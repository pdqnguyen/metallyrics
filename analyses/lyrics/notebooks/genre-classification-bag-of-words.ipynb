# %% [markdown]
# # Multi-genre classification of heavy metal lyrics
#
# The aim of this notebook is to demonstrate a machine learning approach to tagging heavy metal songs with genre labels based on their lyrics alone. The task is to develop a model which will predict for a given piece of text which genre(s) describe the text well.
#
# This notebook will implement and discuss the usage of:
# * Binary relevance as a multi-label classification framework
# * Multi-label classification cross-validation and evaluation metrics
# * Bag-of-words text representation (and why it is favorable over word embeddings for this task)
# * Oversampling methods to curb the effects of imbalanced datasets
# * A wide range of different classification models including:
#     * Logistic regression
#     * Bayesian methods
#     * Ensemble methods
#     * Neural networks

# %% [markdown]
# # Table of contents
#
# 1. [Imports](#imports)
#
# 1. [Data](#data)
#
# 1. [Multi-label classification tools](#mlctools)
#
# 1. [Evaluation metrics](#metrics)
#
# 1. [Pipeline](#pipeline)
#
# 1. [Hyperparameter tuning](#tuning)
#
# 1. [Logistic regression](#logreg)
#
# 1. [SGD classifier](#sgd)
#
# 1. [Naive Bayes](#naivebayes)
#
#     * [Multinomial Naive Bayes](#multinomialnb)
#
#     * [Complement Multinomial Naive Bayes](#complementnb)
#
#     * [Bernoulli Naive Bayes](#bernoullinb)
#
# 1. [Random forest](#rf)
#
# 1. [Gradient boosted model](#gbm)
#
# 1. [Neural network](#nn)
#
# 1. [Stacked model](#stacking)
#
# 1. [Test on new lyrics](#test)

# %% [markdown]
# <a id='imports'></a>
# # Imports

# %%
import glob
import os
import re
from copy import deepcopy
import numpy as np
import pandas as pd
import scipy
from scipy.sparse.csr import csr_matrix
from scipy.sparse.lil import lil_matrix
import itertools

import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
sns.set(font_scale=2)

from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import balanced_accuracy_score, precision_score, recall_score, f1_score, \
confusion_matrix, multilabel_confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB, ComplementNB, BernoulliNB

from skmultilearn.model_selection import IterativeStratification
from skmultilearn.problem_transform import BinaryRelevance, ClassifierChain, LabelPowerset

from keras.models import Sequential
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier

import lightgbm as lgb


import sys
sys.path.append('../scripts/')

from nlp import tokenize
from mlsol import MLSOL
import lyrics_utils as utils
# Out:
# Using TensorFlow backend.
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Fix random seeds

# %%
import random
import tensorflow as tf

seed = 0
os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.set_random_seed(seed)

session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# <a id='data'></a>
# # Data
#
# See the previous chapters for more discussion about the data set. The data set is formatted as an array comprised of one independent variable (lyrics, retrieved from [Dark Lyrics](http://darklyrics.com)) and five dependent variable labels (genres, retrieved from [Metal-Archives](https://www.metal-archives.com)), for each row (song). Here are some things to keep in mind about the data:
# * Each song can belong to any one or more, or none, of the genres. For example, a song can be labeled as thrash metal, or both thrash and power metal, and so on, or it can be unlabeled; it can therefore be predicted to be any combination of labels, or unlabeled, as well. This makes the task of tagging song lyrics with the appropriate genre labels a multi-label classification problem.
# * The dataset is multi-lingual, since heavy metal spans many languages around the world. This will affect classification since there are correlations between genres and country of origin, as show in the previous chapter.
# * The length of song lyrics can vary wildly, but this won't be a big issue in a bag-of-words representation.

# %%
df = pd.read_csv('../bands-ml-10pct.csv')
X = df.pop('lyrics').values
y = df.values
genres = df.columns
print(f"number of songs: {X.shape[0]}")
print(f"number of labels: {y.shape[1]}")
print(f"labels: {list(genres)}")
# Out:
# number of songs: 1355
# number of labels: 4
# labels: ['black', 'death', 'power', 'thrash']

# %% [markdown]
# <a id='mlctools'></a>
# # Multi-label classification methods

# %% [markdown]
# **Binary relevance** is the simplest method of classifying multiple labels at once; it trains an independent classifier for each label, breaking the multi-label problem down into many binary classification problems ([Zhang, M., Li, Y., Liu, X., et al, 2018](http://palm.seu.edu.cn/zhangml/files/FCS'17.pdf)). In this context a binary classifier would be trained on each genre, and a song's genre tags predicted by concatenating the predictions of all genre classifiers. The advantage of this method is that the number of classifiers needed is equal to the number of labels, so the computational cost scales linearly with how many labels we want to predict. However, by assuming that the labels are independent, this method fails to capture correlations between labels. For example, the "heavy" and "power" genre labels are more likely to appear together, so an song's likelihood of being tagged as power metal should be higher if it is also tagged as heavy metal as opposed to, say, black metal. Another issue is that each binary classifier will face a class imbalance problem due to the sparsity of genre tags.
#
# In the **classifier chain** method, a classifier is trained on one label and its output is fed as an additional feature to the next label, and so on until all labels have been exhausted ([Read, J., Pfahringer, B., Holmes., G, Frank, E. 2011](https://www.cs.waikato.ac.nz/~eibe/pubs/chains.pdf)). This again requires only as many classifiers as there are labels, but unlike binary relevance it does learn correlations between labels. However, the correlations it is capable of learning can vary with different chain orders.
#
# Unlike the above two methods, which transform the multi-label problem into multiple independent binary classification problems, the **label powerset** method transforms it into a single multi-class problem by treating every combination of labels as its own class. For example, from the genres in the metal lyrics dataset, "black" + "death", "black" + "power", "black" + "death" + "power" would each yield a new class. This tackles the issue of correlated labels head-on by treating correlations as classes on their own, but comes at the cost of having smaller class sizes to train on and consequently an even bigger class imbalance problem. This issue inspired the **RAndom k-labELsets (RAKEL)** method, which uses an ensemble of classifiers, each trained on a random subset of labels ([Rokach, L., Schclar, A., Itach, E. 2013](https://arxiv.org/ftp/arxiv/papers/1307/1307.1769.pdf)).

# %%
class BinaryRelevance:
    def __init__(self, classifier, labels, thresholds=None):
        self.classifier = classifier
        self.labels = labels
        self.classifiers_ = []
        self.thresholds = thresholds

    def fit(self, X, y):
        for i, label in enumerate(self.labels):
            print('training binary classifier for label: {}'.format(label))
            clf = deepcopy(self.classifier)
            clf.fit(X, y[:, i])
            self.classifiers_.append((label, clf))

    def predict(self, X):
        return self._predict(X).astype(int)

    def predict_proba(self, X):
        return self._predict(X, return_prob=True)

    def _predict(self, X, return_prob=False):
        y = np.zeros((X.shape[0], len(self.classifiers_)))
        for i, (label, clf) in enumerate(self.classifiers_):
            if return_prob:
                y[:, i] = clf.predict_proba(X)[:, 1]
            elif self.thresholds is not None:
                y[:, i] = (clf.predict_proba(X)[:, 1] > self.thresholds[i])
            else:
                y[:, i] = clf.predict(X)
        return y

    def cross_validate(self, X, y, n_splits=5, verbose=False):
        kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=0)
        y_prob, y_valid = np.zeros(y.shape), np.zeros(y.shape)
        for i, label in enumerate(self.labels):
            if verbose:
                print("Training on label '{}'".format(label))
            scores = np.zeros((n_splits, 4))
            confusion_matrices = np.zeros((n_splits, 2, 2))
            for j, (train_idx, valid_idx) in enumerate(kfold.split(X, y[:, i])):
                if verbose:
                    print("Fold {}/{}".format(j + 1, n_splits))
                X_fold_train, y_fold_train = X[train_idx], y[train_idx, i]
                X_fold_valid, y_fold_valid = X[valid_idx], y[valid_idx, i]
                clf = deepcopy(self.classifier)
                clf.fit(X_fold_train, y_fold_train)
                try:
                    y_fold_prob = clf.predict_proba(X_fold_valid)[:, 1]
                except AttributeError:
                    y_fold_prob = clf.predict(X_fold_valid).reshape(-1)
                y_prob[valid_idx, i] = y_fold_prob
                y_valid[valid_idx, i] = y_fold_valid
                y_fold_pred = y_fold_prob.round()
                scores[j, 0] = balanced_accuracy_score(y_fold_valid, y_fold_pred)
                scores[j, 1] = precision_score(y_fold_valid, y_fold_pred)
                scores[j, 2] = recall_score(y_fold_valid, y_fold_pred)
                scores[j, 3] = f1_score(y_fold_valid, y_fold_pred)
                confusion_matrices[j] = confusion_matrix(y_fold_valid, y_fold_pred)
            if verbose:
                avg_accuracy, avg_precision, avg_recall, avg_f1 = scores.mean(axis=0)
                std_accuracy, std_precision, std_recall, std_f1 = scores.std(axis=0)
                print("CV scores:")
                print("Accuracy:    {:.2f} +/- {:.2f}".format(avg_accuracy, std_accuracy))
                print("Precision:   {:.2f} +/- {:.2f}".format(avg_precision, std_precision))
                print("Recall:      {:.2f} +/- {:.2f}".format(avg_recall, std_recall))
                print("F1-score:    {:.2f} +/- {:.2f}".format(avg_f1, std_f1))
                print("Average confusion matrix:")
                print(confusion_matrices.mean(axis=0) / confusion_matrices.sum() * n_splits)
        return MultiLabelClassification(y_valid, y_prob, labels=self.labels)

# %%
class ClassifierChain:
    def __init__(self, classifier, labels):
        self.classifier = classifier
        self.labels = labels
        self.classifiers_ = []

    def fit(self, X, y, verbose=False):
        y_chain = np.zeros((y.shape[0], y.shape[1] - 1))
        for i in range(y.shape[1]):
            if verbose:
                print('training binary classifier for label: {}'.format(i))
            X_ = X.copy()
            y_ = y[:, i]
            clf = deepcopy(self.classifier)
            if isinstance(clf, Pipeline):
                for name, step in clf.steps:
                    try:
                        X_ = step.fit_transform(X_)
                    except AttributeError:
                        try:
                            if len(X_.shape) > 1:
                                X_, y_ = step.fit_resample(X_[:, : X_.shape[1]], y_)
                            else:
                                X_, y_ = step.fit_resample(X_, y_)
                        except AttributeError:
                            if i > 0:
                                X_ = np.concatenate((X_, y_chain[:, : i]), axis=1)
                            step.fit(X_, y_)
                            y_pred = step.predict(X_).reshape(-1)
                            print(X_.shape, y_.shape, y_pred.shape)
            else:
                if i > 0:
                    X_ = np.concatenate((X_, y_chain[:, : i]), axis=1)
                clf.fit(X_, y_)
                y_pred = clf.predict(X_).reshape(-1)
            y_chain[:, i] = y_pred
            self.classifiers_.append(clf)

    def predict(self, X):
        return self._predict(X)

    def predict_proba(self, X):
        return self._predict(X, return_prob=True)

    def _predict(self, X, return_prob=False):
        y, y_chain = np.zeros((2, X.shape[0], len(self.classifiers_)))
        for i, clf in enumerate(self.classifiers_):
            X_ = X.copy()
            y_ = y[:, i]
            if isinstance(clf, Pipeline):
                for name, step in clf.steps:
                    try:
                        X_ = step.transform(X_)
                    except AttributeError:
                        try:
                            if len(X_.shape) > 1:
                                X_, y_ = step.resample(X_[:, : X_.shape[1]], y_)
                            else:
                                X_, y_ = step.resample(X_, y_)
                        except AttributeError:
                            if i > 0:
                                X_ = np.concatenate((X_, y_chain[:, : i]), axis=1)
                            y_pred = step.predict(X_).reshape(-1)
                            y_prob = step.predict_proba(X_)[:, 1].reshape(-1)
            else:
                if i > 0:
                    X_ = np.concatenate((X_, y_chain[:, : i]), axis=1)
                y_pred = clf.predict(X_).reshape(-1)
                y_prob = clf.predict_proba(X_)[:, 1].reshape(-1)
            y_chain[:, i] = y_pred
            if return_prob:
                y[:, i] = y_prob
            else:
                y[:, i] = y_pred
        return y

    def cross_validate(self, X, y, n_splits=5, verbose=False):
        kfold = KFold(n_splits=n_splits, shuffle=True, random_state=0)
        y_prob, y_valid = np.zeros(y.shape), np.zeros(y.shape)
        scores = np.zeros((len(self.labels), n_splits, 4))
        confusion_matrices = np.zeros((len(self.labels), n_splits, 2, 2))
        for i, (train_idx, valid_idx) in enumerate(kfold.split(X, y)):
            if verbose:
                print("Fold {}/{}".format(i + 1, n_splits))
            X_fold_train, y_fold_train = X[train_idx], y[train_idx]
            X_fold_valid, y_fold_valid = X[valid_idx], y[valid_idx]
            clf = deepcopy(self)
            clf.fit(X_fold_train, y_fold_train)
            try:
                y_fold_prob = clf.predict_proba(X_fold_valid)
            except AttributeError:
                y_fold_prob = clf.predict(X_fold_valid)
            y_prob[valid_idx, :] = y_fold_prob
            y_valid[valid_idx, :] = y_fold_valid
            y_fold_pred = y_fold_prob.round()
            for j, label in enumerate(self.labels):
                scores[j, i, 0] = balanced_accuracy_score(y_fold_valid, y_fold_pred)
                scores[j, i, 1] = precision_score(y_fold_valid, y_fold_pred)
                scores[j, i, 2] = recall_score(y_fold_valid, y_fold_pred)
                scores[j, i, 3] = f1_score(y_fold_valid, y_fold_pred)
                confusion_matrices[j, i] = confusion_matrix(y_fold_valid, y_fold_pred)
        if verbose:
            for j, label in enumerate(self.labels):
                avg_accuracy, avg_precision, avg_recall, avg_f1 = scores[j].mean(axis=0)
                std_accuracy, std_precision, std_recall, std_f1 = scores[j].std(axis=0)
                print("CV scores for label {}:".format(label))
                print("Accuracy:    {:.2f} +/- {:.2f}".format(avg_accuracy, std_accuracy))
                print("Precision:   {:.2f} +/- {:.2f}".format(avg_precision, std_precision))
                print("Recall:      {:.2f} +/- {:.2f}".format(avg_recall, std_recall))
                print("F1-score:    {:.2f} +/- {:.2f}".format(avg_f1, std_f1))
                print("Average confusion matrix:")
                print(confusion_matrices[j].mean(axis=0) / confusion_matrices[j].sum() * n_splits)
        return MultiLabelClassification(y_valid, y_prob, labels=self.labels)

# %% [markdown]
# <a id='metrics'></a>
# # Evaluation metrics

# %% [markdown]
# Since binary relevance involves training independent binary classifiers, each classifier can be evaluated during training and cross-validation using the familiar binary classification metrics.
#
# However, evaluating the overall results requires metrics designed for the multi-label output, which are more complicated than the usual evaluation metrics ([Zhang, M., Zhou, Z. 2014](https://cs.nju.edu.cn/zhouzh/zhouzh.files/publication/tkde13rev.pdf)). If $h(\mathbf{x}_i)$ is the model which predicts the labels $Y_i$ based on the independent variables $\mathbf{x}_i$, then over $p$ observations the accuracy, precision, recall, and F scores are defined as
#
# \begin{align}
# \mathrm{accuracy}(h) &= \frac{1}{p}\sum_{i=1}^{p}(\mathrm{fraction\ of\ labels\ in\ common}) &= \frac{1}{p}\sum_{i=1}^{p}\frac{|Y_i \cap h(\mathbf{x}_i)|}{|Y_i \cup h(\mathbf{x}_i)|}\\
# \mathrm{precision}(h) &= \frac{1}{p}\sum_{i=1}^{p}(\mathrm{fraction\ of\ predicted\ labels\ that\ are\ correct}) &= \frac{1}{p}\sum_{i=1}^{p}\frac{|Y_i \cap h(\mathbf{x}_i)|}{|h(\mathbf{x}_i)|}\\
# \mathrm{recall}(h) &= \frac{1}{p}\sum_{i=1}^{p}(\mathrm{fraction\ of\ true\ labels\ that\ were\ predicted\ correctly}) &= \frac{1}{p}\sum_{i=1}^{p}\frac{|Y_i \cap h(\mathbf{x}_i)|}{|Y_i|}\\
# \mathrm{F_1\ score}(h) &= \mathrm{harmonic\ mean\ of\ precision\ and\ recall} &= 2 \left[ \frac{\mathrm{precision}(h) \cdot \mathrm{recall}(h)}{\mathrm{precision}(h) + \mathrm{recall}(h)} \right]
# \end{align}
#
# Another useful metric is the Hamming loss, which is the mean symmetric difference (non-matching genre tags) between the two sets:
#
# $$\mathrm{Hamming}(h) = \frac{1}{p} \sum_{i=1}^{p} |h(\mathbf{x}_i\Delta Y_i|$$
#
# The receiver operating characteristic (ROC) is a common metric for binary classification problems that can be easily extended to multi-label problems. ROC measures the ratio of true positive rate to false positive rate as a function of classification threshold. An ROC curve is generated by varying the threshold over its full range, and the area under the curve (ROC AUC) is often used as another evaluation metric. This can be micro- or macro-averaged across all binary classifiers to evaluate the full multi-label classification model.

# %%
class MultiLabelClassification:
    """Multi-label classification results and evaluation metrics.

    Parameters
    ----------
    true : `numpy.ndarray`
        True values (n_samples, n_labels).

    pred : `numpy.ndarray`
        Predicted probabilities (n_samples, n_labels).

    pred_class : `numpy.ndarray`
        Classification results (n_samples, n_labels).

    labels : array-like
        Label names (str).

    threshold : float or array-like
        If float, `thresh` is a decision threshold for all labels.
        If array-like, `thresh` must be length n_labels, with each
        value a decision threshold for that respective label.


    Attributes
    ----------
    n_samples : int
        Number of samples (rows in `self.true`).

    n_labels : int
        Number of labels (columns in `self.true`).

    accuracy_score : float
        Number of labels in common / overall labels (true and predicted).

    precision_score : float
        Proportion of predicted labels that are correct.

    recall_score : float
        Proportion of true labels that were predicted.

    f1_score : float
        Harmonic mean of precision_score and recall_score.

    hamming_loss : float
        Symmetric difference b/w pred and true labels (true XOR pred).


    Methods
    -------
    print_report
    best_thresholds
    roc_auc_score
    plot_roc_curve
    plot_precision_recall_curve
    to_csv
    from_csv
    """

    def __init__(
            self,
            true,
            pred=None,
            pred_class=None,
            labels=None,
            threshold=0.5
    ):
        self.true = true.astype(int)
        self.pred = pred
        self.threshold = threshold
        if pred_class is None:
            pred_class = np.zeros_like(self.pred, dtype=int)
            if hasattr(self.threshold, '__iter__'):
                thresh_tile = np.ones_like(self.true) * self.threshold
            else:
                thresh_tile = np.tile(self.threshold, (self.true.shape[0], 1))
            pred_class[self.pred > thresh_tile] = 1
        self.pred_class = pred_class
        self.n_samples, self.n_labels = self.true.shape
        if labels is not None:
            if len(labels) == self.n_labels:
                self.labels = np.array(labels, dtype='object')
            else:
                raise ValueError(
                    f"len(labels)={len(labels)} does not match "
                    f"true.shape[1]={self.n_labels}")
        else:
            self.labels = np.arange(self.true.shape[1]).astype(str).astype('object')

    @property
    def __intersection(self):
        return self.true * self.pred_class

    @property
    def __union(self):
        return np.minimum(1, self.true + self.pred_class)

    @property
    def accuracy_score(self):
        return np.nanmean(self.__intersection.sum(1) / self.__union.sum(1))

    @property
    def precision_score(self):
        return np.nanmean(self.__intersection.sum(1) / self.pred_class.sum(1))

    @property
    def recall_score(self):
        return np.nanmean(self.__intersection.sum(1) / self.true.sum(1))

    @property
    def f1_score(self):
        prec = self.precision_score
        rec = self.recall_score
        return 2 * prec * rec / (prec + rec)

    @property
    def hamming_loss(self):
        delta = np.zeros(self.true.shape[0])
        for i in range(delta.shape[0]):
            delta[i] = np.sum(self.true[i] ^ self.pred_class[i])
        return delta.mean()

    @property
    def roc_auc_score(self):
        """Area under receiver operating characteristic (ROC) curve.
        """
        auc = np.zeros(len(self.labels))
        for i, label in enumerate(self.labels):
            auc[i] = roc_auc_score(self.true[:, i], self.pred[:, i])
        return auc

    def print_report(self, full=False):
        """Print results of classification.
        """
        np.seterr(divide='ignore', invalid='ignore')
        if full:
            print("\nBinary classification metrics:")
        metrics = [
            'balanced_accuracy_score', 'precision_score',
            'recall_score', 'f1_score']
        exec(f"from sklearn.metrics import {', '.join(metrics)}")
        scores = {metric: np.zeros(self.n_labels) for metric in metrics}
        for i, label in enumerate(self.labels):
            if full:
                print(f"\nlabel: {label}")
            true_i = self.true[:, i]
            pred_i = self.pred_class[:, i]
            for metric in metrics:
                score = eval(f"{metric}(true_i, pred_i)")
                scores[metric][i] = score
                if full:
                    print(f"  {metric.replace('_score', '')[:19]:<20s}"
                          f"{score:.3f}")
            cfm = confusion_matrix(true_i, pred_i)
            if full:
                print("  confusion matrix:")
                print(f"  [[{cfm[0, 0]:6.0f} {cfm[0, 1]:6.0f}]\n"
                      f"   [{cfm[1, 0]:6.0f} {cfm[1, 1]:6.0f}]]")
        print(f"\nAverage binary classification scores:")
        for metric in metrics:
            avg = scores[metric].mean()
            std = scores[metric].std()
            print(f"  {metric.replace('_score', '')[:19]:<20s}"
                  f"{avg:.2f} +/- {std * 2:.2f}")
        print("\nMulti-label classification metrics:")
        print(f"  accuracy      {self.accuracy_score:.2f}")
        print(f"  precision     {self.precision_score:.2f}")
        print(f"  recall        {self.recall_score:.2f}")
        print(f"  f1            {self.f1_score:.2f}")
        print(f"  hamming loss  {self.hamming_loss:.2f}")
        auc_scores = self.roc_auc_score
        print(f"\nROC AUC scores:")
        for label, auc_score in zip(self.labels, auc_scores):
            print(f"  {label:<10s}: {auc_score:.3f}")
        print(f"  macro-avg : {np.mean(auc_scores):.3f} "
              f"+/- {np.std(auc_scores):.3f}")
        return

    def best_thresholds(self, metric='gmean', fbeta=1):
        """Determine best thresholds by maximizing geometric mean
        or f_beta score.
        """
        best = np.zeros(len(self.labels))
        for i, label in enumerate(self.labels):
            true, pred = self.true[:, i], self.pred[:, i]
            if metric == 'gmean':
                fpr, tpr, thresholds = roc_curve(true, pred)
                gmean = np.sqrt(tpr * (1 - fpr))
                best[i] = thresholds[gmean.argmax()]
            elif metric == 'fscore':
                prec, rec, thresholds = precision_recall_curve(true, pred)
                fscore = ((1 + fbeta**2) * prec * rec) / ((fbeta**2 * prec) + rec)
                best[i] = thresholds[fscore.argmax()]
        return best

    def plot_roc_curve(self):
        """Plot receiver-operating characteristic (ROC) curve.
        """
        fig, ax = plt.subplots(1, 1, figsize=(8, 6))
        for i, label in enumerate(self.labels):
            true = self.true[:, i]
            pred = self.pred[:, i]
            fpr, tpr, thresholds = roc_curve(true, pred)
            ax.step(fpr, tpr, label=label)
        ax.plot([0, 1], [0, 1], 'k--')
        ax.set_aspect('equal')
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_title("ROC curve")
        ax.set_xlabel("False positive rate")
        ax.set_ylabel("True positive rate")
        ax.legend()
        ax.grid(True)
        fig.tight_layout()
        return fig

    def plot_precision_recall_curve(self):
        """Plot precision and recall against decision threshold.
        """
        fig, ax = plt.subplots(1, 1, figsize=(8, 6))
        for i, label in enumerate(self.labels):
            true, pred = self.true[:, i], self.pred[:, i]
            prec, rec, thresholds = precision_recall_curve(true, pred)
            line = ax.plot(thresholds, prec[:-1], label=label)
            ax.plot(thresholds, rec[:-1], ":", color=line[0].get_color())
        ax.set_aspect('equal')
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_title("Precision and recall scores")
        ax.set_xlabel("Decision threshold")
        ax.set_ylabel("Score")
        ax.text(0.01, 0.01, "solid lines show precision score\n"
                "dotted lines show recall score", size=16)
        ax.legend(loc='upper right')
        ax.grid(True)
        fig.tight_layout()
        return fig

    def to_csv(self, filename):
        """Save true labels, probabilities, and predictions to CSV.
        """
        data = {}
        for i, label in enumerate(self.labels):
            data[f"{label}_true"] = self.true[:, i]
            data[f"{label}_pred"] = self.pred[:, i]
            data[f"{label}_pred_class"] = self.pred_class[:, i]
        df = pd.DataFrame.from_dict(data)
        df.to_csv(filename, index=False)
        return

    @classmethod
    def from_csv(cls, filename):
        """Load classification from CSV.
        """
        data = pd.read_csv(filename)
        cols = data.columns
        true = data[[c for c in cols if c[-4:] == 'true']].values
        pred = data[[c for c in cols if c[-4:] == 'pred']].values
        labels = [c.replace('_true', '') for c in cols if c[-4:] == 'true']
        pred_class = data[[c for c in cols if c[-10:] == 'pred_class']].values
        new = cls(true, pred, pred_class=pred_class, labels=labels)
        return new

# %% [markdown]
# <a id='pipeline'></a>
# # Pipeline

# %% [markdown]
# Two pre-processing steps must be performed before a model can be trained on this dataset:
#
# 1. **Vectorization**: To transform the data from raw song lyrics to an array of values ready for training, the lyrics must be vectorized. In this notebook this will be done using a bag-of-words representation, which simply transforms the corpus into a matrix whose rows represent documents (songs) and columns represent words. The value of each word in a document is determined by the vectorization method. The `CountVectorizer` will populate this matrix with raw word counts; the `TfidfVectorizer` takes this an extra step by computing the term-frequency inverse-document-frequency (TF-IDF) value for each term in a document. TF-IDF measures the frequency of a term in a document relative to its frequency in all documents, thus providing a better measure of how unique the term is to that document.
#
#     A shortcoming of the bag-of-words representation is that it fails to capture any syntactical structure in the lyrics. A popular alternative is to implement a [word embedding](https://en.wikipedia.org/wiki/Word_embedding), which generates a vector space representation of all the words in the data set, Since this method allows a document to be transformed into series of word-vectors, it opens up the possibility of training models that is sensitive to the word ordering. That said, in the case of song lyrics, syntax is usually unimportant, if it even exists. Lyrics are often comprised of broken phrases that combine words in unusual ways and may not necessarily convey meaning in the way that prose sentences do. Punctuation is scarce, its usage often a stylistic decision of the transcriber. For these reasons, a bag-of-words representation should suffice, and may even outperform word embeddings.
#
# 2. **Oversampling**: To remedy the class imbalance in each single-genre binary classification, the data can be either oversampled or undersampled to have an equal number of positive and negative class occurrences. Undersampling requires no manipulation of the data; the classifier is simply trained with a subset of the majority class equal in number to the minority class. This comes at the cost of reducing the amount of data to train from, so oversampling is often preferred over undersampling. The simplest method of oversampling is random oversampling, in which randomly selected rows from the minority class are duplicated during training. Synthetic Minority Oversampling Technique (SMOTE) is a more complex method that generates new data based on the distribution of values in the minority class [Chawla, N., Bowyer, K., Hall, L., Kegelmeyer, W. 2011](https://arxiv.org/abs/1106.1813). It does so by randomly selecting two observations at a time in the minority class and sampling a new observation from the line between those two in the feature space. This is somewhat like producing from randomly selected parent observations a child whose traits are somewhere between those of its parents. In the context of song lyrics SMOTE would generate new songs with word frequencies (or TF-IDF values) similar to the genre being classified by the binary classifier.

# %%
class NLPipeline:
    """Pipeline for NLP classification with vectorization and resampling

    Parameters
    ----------
    vectorizer : transformer object
        Object with `fit_transform` and `transform` methods for vectorizing
        corpus data.

    resampler : resampler object
        Object with fit_resample method for resampling training data in
        `Pipeline.fit`. This can be any under/oversampler from `imblearn`
        for binary or multiclass classification, or `MLSOL` from
        https://github.com/diliadis/mlsol/blob/master/MLSOL.py for multi-label
        classification.

    classifier : estimator object
        Binary, multi-class, or multi-label classifier with a `predict`
        or `predict_proba` method.

    Methods
    -------
    fit(X, y)
        Fit vectorizer and resampler, then train classifier on transformed data.

    predict(X)
        Return classification probabilities (if `self.classifier` has a
        `predict_proba` method, otherwise return predictions using `predict`).
    """
    def __init__(self, vectorizer, resampler, classifier, pad_features=False):
        self.vectorizer = vectorizer
        self.resampler = resampler
        self.classifier = classifier
        self.pad_features = pad_features
        self.threshold = None
        self.labels = None

    @property
    def features(self):
        feature_names = self.vectorizer.get_feature_names()
        if self.pad_features:
            feature_names + [''] * self.padding
        return 

    def fit(self, X, y, labels=None):
        self.labels = labels
        X_v = self.vectorizer.fit_transform(X).toarray()
        if self.pad_features:
            self.padding = self.vectorizer.max_features - len(self.vectorizer.get_feature_names())
            if self.padding > 0:
                padding_array = np.zeros((X_v.shape[0], self.padding))
                X_v = np.concatenate((X_v, padding_array), axis=1)
        X_r, y_r = self.resampler.fit_resample(X_v, y)
        self.classifier.fit(X_r, y_r)
        return self

    def predict(self, X):
        X_v = self.vectorizer.transform(X)
        try:
            y_p = self.classifier.predict_proba(X_v)
        except AttributeError:
            y_p = self.classifier.predict(X_v)
        if (
                isinstance(y_p, csr_matrix) or
                isinstance(y_p, lil_matrix)
        ):
            y_p = y_p.toarray()
        return y_p

    def set_threshold(self, threshold):
        self.threshold = threshold
        return

    def classify_text(self, text):
        X_test = np.array([' '.join(text.lower().split())])
        prob = self.predict(X_test)[0]
        if self.threshold is not None:
            pred = prob > self.threshold
        else:
            pred = prob > 0.5
        if self.labels is not None:
            labels = self.labels
        else:
            labels = range(len(pred))
        results = [(label, prob[i], pred[i]) for i, label in enumerate(labels)]
        results.sort(key=lambda x: 1 - x[1])
        print("Classification:")
        if results[0][2] < 1:
            print("NONE")
        else:
            print(", ".join([res[0].upper() for res in results if res[2] > 0]))
        print("\nIndividual label probabilities:")
        for res in results:
            print("{:<10s}{:>3.0f}%".format(res[0], 100 * res[1]))
        return

# %%
def multilabel_pipeline_cross_val(pipeline, X, y, labels=None, n_splits=3, verbose=0):
    """Multi-label pipeline cross-validation

    Parameters
    ----------
    pipeline : `sklearn.pipeline.Pipeline` or custom pipeline
        Must have .fit and .predict methods

    X : array-like

    y : array-like
        (n_samples x n_labels)

    labels : array-like
        Label names (numerical if Default = None)

    n_splits : int
        Number of cross-validation splits (Default = 3)

    Returns
    -------
    mlc : `multilabel.MultiLabelClassification`
        Multi-label classification results

    folds : list
        (train_idx, valid_idx) pair for each CV fold
    """
    kfold = IterativeStratification(n_splits=n_splits, order=1, random_state=0)
    pred = np.zeros_like(y, dtype=float)
    thresh_folds = np.zeros((y.shape[1], n_splits))
    for i, (train_idx, valid_idx) in enumerate(kfold.split(X, y)):
        if verbose > 0:
            print(f"\n--------\nFold {i+1}/{kfold.n_splits}")
        X_train, y_train = X[train_idx], y[train_idx]
        X_valid, y_valid = X[valid_idx], y[valid_idx]
        pipeline.fit(X_train, y_train, labels=labels)
        valid_pred = pipeline.predict(X_valid)
        pred[valid_idx] = valid_pred
        mlc_valid = MultiLabelClassification(y_valid, valid_pred, labels=labels)
        thresh_folds[:, i] = mlc_valid.best_thresholds('gmean')
        if verbose > 0:
            mlc_valid.print_report(full=(verbose > 1))
    threshold = thresh_folds.mean(axis=1)
    mlc = MultiLabelClassification(
        y, pred=pred, labels=labels, threshold=threshold)
    if verbose > 0:
        print("\n------------------------\nCross-validation results")
        mlc.print_report(full=True)#(verbose > 1))
    return mlc

# %%
test_corpus = ['', 'satan', 'flesh', 'fight', 'attack']

# %% [markdown]
# ### Vectorization example

# %%
def tokenizer(s):
    tokens = tokenize(s.strip(), english_only=True)
    tokens = [t for t in tokens if len(t) >= 4]
    return tokens

# %%
vectorizer = TfidfVectorizer(
    stop_words=stopwords.words('english'),
    tokenizer=tokenizer,
    min_df=0.1,
    max_df=0.9,
    max_features=500,
    sublinear_tf=False,
)
X_v = vectorizer.fit_transform(X)

print("Vocab size:", X_v.shape[1])
# Out:
# Vocab size: 500

# %%
vocab = np.array(vectorizer.get_feature_names())


def sort_vocab(i):
    return vocab[X_v.toarray()[i].argsort()]


print(sort_vocab(15)[-20:])
# Out:
# ['flesh' 'torn' 'fate' 'pain' 'control' 'trapped' 'another' 'lost' 'fear'
#  'minds' 'dreams' 'every' 'know' 'within' 'truth' 'reality' 'soul'
#  'thoughts' 'lies' 'self']

# %% [markdown]
# <a id='logreg'></a>
# # Logistic regression
#
# One very simple model for a binary classification task is the [`LogisticRegression`](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression) classifier, which assumes a linear relationship between the feature variables (word counts) and the log-odds of the target variables (genre). Logistic regression is a very common tool for tackling classification problems in a variety of applications, sometimes under the names logit regression or maximum-entropy (MaxEnt) classification.

# %% [markdown]
# ### Vectorizer parameter tuning

# %%
lr_params = dict(
    solver='lbfgs',
    max_iter=1000,
    random_state=0
)
params = {
    'min_df': [0.1, 0.3],
    'max_df': [0.8, 0.9, 0.95],
    'max_features': [500, 1000, 3000],
}
param_grid = list(itertools.product(*params.values()))
results = []
for min_df, max_df, max_features in param_grid:
    vectorizer = TfidfVectorizer(
        stop_words=stopwords.words('english'),
        tokenizer=tokenizer,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        sublinear_tf=False,
    )
    pipeline = Pipeline(
        vectorizer=vectorizer,
        resampler=MLSOL(perc_gen_instances=0.3, k=5),
        classifier=BinaryRelevance(
            LogisticRegression(**lr_params),
            require_dense=[False, True]
        )
    )
    mlc, _ = multilabel_pipeline_cross_val(pipeline, X[::20], y[::20], labels=genres)
    results.append(mlc)
# Out:
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3
# fold 1/3
# fold 2/3
# fold 3/3

# %%
for p, res in zip(param_grid, results):
    print(p, f"{res.f1_score:.3f}, {res.hamming_loss:.3f}, {np.mean(res.roc_auc_score()):.3f}")
# Out:
# (0.1, 0.8, 500) 0.335, 1.147, 0.730
# (0.1, 0.8, 1000) 0.477, 0.868, 0.806
# (0.1, 0.8, 3000) 0.364, 0.926, 0.762
# (0.1, 0.9, 500) 0.490, 0.868, 0.772
# (0.1, 0.9, 1000) 0.454, 0.971, 0.744
# (0.1, 0.9, 3000) 0.372, 1.059, 0.731
# (0.1, 0.95, 500) 0.467, 0.912, 0.794
# (0.1, 0.95, 1000) 0.460, 0.912, 0.802
# (0.1, 0.95, 3000) 0.408, 0.971, 0.768
# (0.3, 0.8, 500) 0.455, 0.897, 0.782
# (0.3, 0.8, 1000) 0.476, 0.809, 0.778
# (0.3, 0.8, 3000) 0.357, 1.015, 0.791
# (0.3, 0.9, 500) 0.431, 1.029, 0.765
# (0.3, 0.9, 1000) 0.427, 0.868, 0.786
# (0.3, 0.9, 3000) 0.471, 1.015, 0.781
# (0.3, 0.95, 500) 0.317, 0.897, 0.780
# (0.3, 0.95, 1000) 0.298, 0.926, 0.766
# (0.3, 0.95, 3000) 0.479, 1.044, 0.784
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\philippe\Anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ### Best parameters

# %%
vectorizer = TfidfVectorizer(
    stop_words=stopwords.words('english'),
    tokenizer=tokenizer,
    min_df=0.1,
    max_df=0.9,
    max_features=1000,
    sublinear_tf=False,
)

# %%
lr_params = dict(
    solver='liblinear',
    C=5.0,
    max_iter=1000,
    random_state=0
)
lr_pipeline = NLPipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5, random_state=0),
    classifier=BinaryRelevance(
        LogisticRegression(**lr_params),
        require_dense=[False, True]
    )
)

lr_mlc = multilabel_pipeline_cross_val(lr_pipeline, X, y, labels=genres, verbose=2)
lr_mlc.plot_roc_curve()
plt.show()
lr_mlc.plot_precision_recall_curve()
plt.show()
# Out:
# --------
# Fold 1/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 851.66it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.743
#   precision           0.732
#   recall              0.550
#   f1                  0.628
#   confusion matrix:
#   [[   321     22]
#    [    49     60]]
#
# label: death
#   balanced_accuracy   0.688
#   precision           0.645
#   recall              0.523
#   f1                  0.578
#   confusion matrix:
#   [[   255     44]
#    [    73     80]]
#
# label: power
#   balanced_accuracy   0.760
#   precision           0.809
#   recall              0.543
#   f1                  0.650
#   confusion matrix:
#   [[   373      9]
#    [    32     38]]
#
# label: thrash
#   balanced_accuracy   0.684
#   precision           0.615
#   recall              0.421
#   f1                  0.500
#   confusion matrix:
#   [[   356     20]
#    [    44     32]]
#
# Average binary classification scores:
#   balanced_accuracy   0.72 +/- 0.07
#   precision           0.70 +/- 0.15
#   recall              0.51 +/- 0.10
#   f1                  0.59 +/- 0.12
#
# Multi-label classification metrics:
#   accuracy      0.46
#   precision     0.71
#   recall        0.54
#   f1            0.61
#   hamming loss  0.65
#
# ROC AUC scores:
#   black     : 0.897
#   death     : 0.813
#   power     : 0.942
#   thrash    : 0.836
#   macro-avg : 0.872 +/- 0.051
#
# --------
# Fold 2/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 927.99it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.770
#   precision           0.756
#   recall              0.602
#   f1                  0.670
#   confusion matrix:
#   [[   322     21]
#    [    43     65]]
#
# label: death
#   balanced_accuracy   0.717
#   precision           0.694
#   recall              0.562
#   f1                  0.621
#   confusion matrix:
#   [[   260     38]
#    [    67     86]]
#
# label: power
#   balanced_accuracy   0.782
#   precision           0.837
#   recall              0.586
#   f1                  0.689
#   confusion matrix:
#   [[   373      8]
#    [    29     41]]
#
# label: thrash
#   balanced_accuracy   0.693
#   precision           0.711
#   recall              0.421
#   f1                  0.529
#   confusion matrix:
#   [[   362     13]
#    [    44     32]]
#
# Average binary classification scores:
#   balanced_accuracy   0.74 +/- 0.07
#   precision           0.75 +/- 0.11
#   recall              0.54 +/- 0.14
#   f1                  0.63 +/- 0.12
#
# Multi-label classification metrics:
#   accuracy      0.50
#   precision     0.77
#   recall        0.59
#   f1            0.67
#   hamming loss  0.58
#
# ROC AUC scores:
#   black     : 0.909
#   death     : 0.791
#   power     : 0.938
#   thrash    : 0.885
#   macro-avg : 0.881 +/- 0.055
#
# --------
# Fold 3/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 947.37it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.752
#   precision           0.721
#   recall              0.574
#   f1                  0.639
#   confusion matrix:
#   [[   320     24]
#    [    46     62]]
#
# label: death
#   balanced_accuracy   0.725
#   precision           0.720
#   recall              0.559
#   f1                  0.630
#   confusion matrix:
#   [[   267     33]
#    [    67     85]]
#
# label: power
#   balanced_accuracy   0.783
#   precision           0.764
#   recall              0.600
#   f1                  0.672
#   confusion matrix:
#   [[   369     13]
#    [    28     42]]
#
# label: thrash
#   balanced_accuracy   0.666
#   precision           0.750
#   recall              0.355
#   f1                  0.482
#   confusion matrix:
#   [[   367      9]
#    [    49     27]]
#
# Average binary classification scores:
#   balanced_accuracy   0.73 +/- 0.09
#   precision           0.74 +/- 0.04
#   recall              0.52 +/- 0.19
#   f1                  0.61 +/- 0.15
#
# Multi-label classification metrics:
#   accuracy      0.48
#   precision     0.75
#   recall        0.57
#   f1            0.65
#   hamming loss  0.60
#
# ROC AUC scores:
#   black     : 0.908
#   death     : 0.817
#   power     : 0.928
#   thrash    : 0.836
#   macro-avg : 0.872 +/- 0.047
#
# ------------------------
# Cross-validation results
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.827
#   precision           0.573
#   recall              0.855
#   f1                  0.686
#   confusion matrix:
#   [[   823    207]
#    [    47    278]]
#
# label: death
#   balanced_accuracy   0.718
#   precision           0.598
#   recall              0.664
#   f1                  0.629
#   confusion matrix:
#   [[   693    204]
#    [   154    304]]
#
# label: power
#   balanced_accuracy   0.855
#   precision           0.523
#   recall              0.852
#   f1                  0.649
#   confusion matrix:
#   [[   982    163]
#    [    31    179]]
#
# label: thrash
#   balanced_accuracy   0.777
#   precision           0.440
#   recall              0.746
#   f1                  0.554
#   confusion matrix:
#   [[   911    216]
#    [    58    170]]
#
# Average binary classification scores:
#   balanced_accuracy   0.79 +/- 0.10
#   precision           0.53 +/- 0.12
#   recall              0.78 +/- 0.16
#   f1                  0.63 +/- 0.10
#
# Multi-label classification metrics:
#   accuracy      0.50
#   precision     0.57
#   recall        0.79
#   f1            0.66
#   hamming loss  0.80
#
# ROC AUC scores:
#   black     : 0.904
#   death     : 0.807
#   power     : 0.936
#   thrash    : 0.851
#   macro-avg : 0.874 +/- 0.049

# %%
print("Thresholds:", lr_mlc.threshold)
lr_pipeline.fit(X, y, labels=genres)

lr_pipeline.set_threshold(lr_mlc.threshold)

for text in test_corpus:
    lr_pipeline.classify_text(text)
    print()
# Out:
# Thresholds: [0.23031295 0.38649019 0.20950044 0.19132428]
# 100%|███████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 833.68it/s]
# Classification:
# BLACK
#
# Individual label probabilities:
# black      33%
# death       4%
# thrash      4%
# power       1%
#
# Classification:
# BLACK
#
# Individual label probabilities:
# black      83%
# thrash      3%
# death       2%
# power       0%
#
# Classification:
# DEATH, BLACK
#
# Individual label probabilities:
# death      84%
# black      27%
# thrash      0%
# power       0%
#
# Classification:
# POWER
#
# Individual label probabilities:
# power      31%
# black      12%
# thrash      3%
# death       1%
#
# Classification:
# THRASH, BLACK
#
# Individual label probabilities:
# thrash     57%
# black      33%
# death       6%
# power       1%

# %% [markdown]
# ### Feature importances

# %%
for clf in lr_pipeline.classifier.classifiers_:
    fi = clf.coef_[0]
    fi_top = fi.argsort()[-10:]
    x_vals = range(len(fi_top))
    fig = plt.figure(figsize=(8, 5))
    plt.bar(x_vals, fi[fi_top])
    plt.xticks(x_vals, np.array(lr_pipeline.vocabulary)[fi_top], rotation=45)
    plt.show()

# %% [markdown]
# <a id='sgd'></a>
# # SGD Classifier

# %% [markdown]
# The scikit-learn [`SGDClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html) is a generalized classifier that trains via stochastic gradient descent (SGD). It can assume the form of a logistic regression if using 'log' loss, but by default it uses the 'hinge' loss in which case the linear model it fits is a linear support vector machine (SVM).

# %%
pipeline = Pipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5),
    classifier=BinaryRelevance(
        SGDClassifier(loss='modified_huber', alpha=0.0001),
        require_dense=[False, True]
    )
)
mlc, _ = multilabel_pipeline_cross_val(pipeline, X, y, labels=genres)
mlc.print_report()
best_thresh = mlc.thresh
if isinstance(best_thresh, float):
    best_thresh = np.ones(mlc.n_labels) * best_thresh
if len(best_thresh.shape) == 2:
    best_thresh = best_thresh.mean(0)
print("\nDecision thresholds:")
for i, label in enumerate(mlc.labels):
    print(f"  {label:<10s}: {best_thresh[i]:.2f}")
mlc.plot_roc_curve()
plt.show()
mlc.plot_precision_recall_curve()
plt.show()
# Out:
# fold 1/3
# fold 2/3
# fold 3/3
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.712
#   precision           0.588
#   recall              0.545
#   f1                  0.565
#   confusion matrix:
#   [[   906    124]
#    [   148    177]]
#
# label: death
#   balanced_accuracy   0.658
#   precision           0.548
#   recall              0.544
#   f1                  0.546
#   confusion matrix:
#   [[   692    205]
#    [   209    249]]
#
# label: power
#   balanced_accuracy   0.759
#   precision           0.510
#   recall              0.629
#   f1                  0.563
#   confusion matrix:
#   [[  1018    127]
#    [    78    132]]
#
# label: thrash
#   balanced_accuracy   0.667
#   precision           0.438
#   recall              0.452
#   f1                  0.445
#   confusion matrix:
#   [[   995    132]
#    [   125    103]]
#
# Average binary classification scores:
#   balanced_accuracy   0.70 +/- 0.08
#   precision           0.52 +/- 0.11
#   recall              0.54 +/- 0.13
#   f1                  0.53 +/- 0.10
#
# Multi-label classification metrics:
#   accuracy      0.40
#   precision     0.55
#   recall        0.56
#   f1            0.56
#   hamming loss  0.85
#
# ROC AUC scores:
#   black     : 0.791
#   death     : 0.706
#   power     : 0.824
#   thrash    : 0.730
#   macro-avg : 0.763 +/- 0.047
#
# Decision thresholds:
#   black     : 0.62
#   death     : 0.50
#   power     : 0.38
#   thrash    : 0.55

# %% [markdown]
# <a id='naivebayes'></a>
# # Naive Bayes

# %% [markdown]
# [Naive Bayes classifiers](https://en.wikipedia.org/wiki/Naive_Bayes_classifier) have long been popular in text classification. The method is rooted in Bayes' Theorem, which states the probability of a particular class $y$ given input $\mathbf{x}=(x_1, \dots, x_n)$ can be written as
#
# $$ P(y|\mathbf{x}) = \frac{P(y)P(\mathbf{x}|y)}{P(\mathbf{x})} $$
#
# where $P(y)$, $P(\mathbf{x}|y)$, and $P(\mathbf{x})$ are known as the prior, likelihood and evidence. The evidence is class-independent and can be ignored when comparing the probabilities of different classes, while the likelihood can be expanded using the chain rule for probabilities as
#
# \begin{align}
# P(\mathbf{x}|y) &= P(x_1, \dots, x_n|y)\\
#                 &= P(x_1|x_2, \dots, x_n, y) P(x_2, \dots, x_n|y)\\
#                 &= \dots\\
#                 &= P(x_1|x_2, \dots, x_n, y) P(x_2| x_3 \dots, x_n, y) \dots P(x_{n-1}|x_n, y) P(x_n|y) P(y)
# \end{align}
#
# The "naive" assumption is that the input variables $x_i$ are assumed to be mutually independent, so $P(x_i|x_{i+1}, \dots, x_n, y) = P(x_i|y)$. Thus the likelihood becomes a product sum of single-feature probabilities $P(x_i|y)$:
#
# $$ P(\mathbf{x}|y) = P(y) \prod_{i=1}^{n} P(x_i|y) $$
#
# Thus the Naive Bayes classification problem can be expressed as a maximum a posteriori estimation (like maximum-likelihood but with a prior term included that behaves like a regularization parameter (see [this blog post](https://wiseodd.github.io/techblog/2017/01/01/mle-vs-map/) for a quick discussion of MAP and MLE)) with the following classification rule:
#
# $$ \hat{y} = \mathrm{argmax}_k P(y_k) \prod_{i=1}^{n} P(x_i|y_k) $$
#
# The scikit-learn implementation [`NaiveBayes`](https://scikit-learn.org/stable/modules/naive_bayes.html#naive-bayes) provides different options for the likelihood distribution $P(x_i|y)$. The Multinomial and Bernoulli algorithms are the most popular for document classification tasks.

# %% [markdown]
# <a id='multinomialnb'></a>
# ### Multinomial Naive Bayes

# %%
multinomial_pipeline = NLPipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5, random_state=0),
    classifier=BinaryRelevance(
        MultinomialNB(alpha=1.0),
        require_dense=[False, True]
    )
)
multinomial_mlc = multilabel_pipeline_cross_val(multinomial_pipeline, X, y, labels=genres, verbose=2)
multinomial_mlc.plot_roc_curve()
plt.show()
multinomial_mlc.plot_precision_recall_curve()
plt.show()
# Out:
# --------
# Fold 1/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 882.26it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.730
#   precision           0.645
#   recall              0.556
#   f1                  0.597
#   confusion matrix:
#   [[   311     33]
#    [    48     60]]
#
# label: death
#   balanced_accuracy   0.663
#   precision           0.605
#   recall              0.490
#   f1                  0.542
#   confusion matrix:
#   [[   250     49]
#    [    78     75]]
#
# label: power
#   balanced_accuracy   0.621
#   precision           0.750
#   recall              0.257
#   f1                  0.383
#   confusion matrix:
#   [[   376      6]
#    [    52     18]]
#
# label: thrash
#   balanced_accuracy   0.575
#   precision           0.619
#   recall              0.171
#   f1                  0.268
#   confusion matrix:
#   [[   368      8]
#    [    63     13]]
#
# Average binary classification scores:
#   balanced_accuracy   0.65 +/- 0.11
#   precision           0.65 +/- 0.11
#   recall              0.37 +/- 0.32
#   f1                  0.45 +/- 0.26
#
# Multi-label classification metrics:
#   accuracy      0.33
#   precision     0.66
#   recall        0.42
#   f1            0.51
#   hamming loss  0.75
#
# ROC AUC scores:
#   black     : 0.855
#   death     : 0.754
#   power     : 0.905
#   thrash    : 0.810
#   macro-avg : 0.831 +/- 0.056
#
# --------
# Fold 2/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 909.00it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.712
#   precision           0.644
#   recall              0.514
#   f1                  0.571
#   confusion matrix:
#   [[   312     31]
#    [    53     56]]
#
# label: death
#   balanced_accuracy   0.670
#   precision           0.667
#   recall              0.458
#   f1                  0.543
#   confusion matrix:
#   [[   264     35]
#    [    83     70]]
#
# label: power
#   balanced_accuracy   0.657
#   precision           0.686
#   recall              0.343
#   f1                  0.457
#   confusion matrix:
#   [[   371     11]
#    [    46     24]]
#
# label: thrash
#   balanced_accuracy   0.559
#   precision           0.667
#   recall              0.132
#   f1                  0.220
#   confusion matrix:
#   [[   371      5]
#    [    66     10]]
#
# Average binary classification scores:
#   balanced_accuracy   0.65 +/- 0.11
#   precision           0.67 +/- 0.03
#   recall              0.36 +/- 0.29
#   f1                  0.45 +/- 0.28
#
# Multi-label classification metrics:
#   accuracy      0.35
#   precision     0.68
#   recall        0.42
#   f1            0.52
#   hamming loss  0.73
#
# ROC AUC scores:
#   black     : 0.865
#   death     : 0.790
#   power     : 0.911
#   thrash    : 0.806
#   macro-avg : 0.843 +/- 0.048
#
# --------
# Fold 3/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 818.66it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.757
#   precision           0.667
#   recall              0.611
#   f1                  0.638
#   confusion matrix:
#   [[   310     33]
#    [    42     66]]
#
# label: death
#   balanced_accuracy   0.706
#   precision           0.638
#   recall              0.579
#   f1                  0.607
#   confusion matrix:
#   [[   249     50]
#    [    64     88]]
#
# label: power
#   balanced_accuracy   0.564
#   precision           0.500
#   recall              0.157
#   f1                  0.239
#   confusion matrix:
#   [[   370     11]
#    [    59     11]]
#
# label: thrash
#   balanced_accuracy   0.563
#   precision           0.833
#   recall              0.132
#   f1                  0.227
#   confusion matrix:
#   [[   373      2]
#    [    66     10]]
#
# Average binary classification scores:
#   balanced_accuracy   0.65 +/- 0.17
#   precision           0.66 +/- 0.24
#   recall              0.37 +/- 0.45
#   f1                  0.43 +/- 0.39
#
# Multi-label classification metrics:
#   accuracy      0.35
#   precision     0.67
#   recall        0.44
#   f1            0.53
#   hamming loss  0.73
#
# ROC AUC scores:
#   black     : 0.859
#   death     : 0.801
#   power     : 0.847
#   thrash    : 0.840
#   macro-avg : 0.837 +/- 0.022
#
# ------------------------
# Cross-validation results
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.775
#   precision           0.525
#   recall              0.769
#   f1                  0.624
#   confusion matrix:
#   [[   804    226]
#    [    75    250]]
#
# label: death
#   balanced_accuracy   0.699
#   precision           0.553
#   recall              0.677
#   f1                  0.608
#   confusion matrix:
#   [[   646    251]
#    [   148    310]]
#
# label: power
#   balanced_accuracy   0.802
#   precision           0.424
#   recall              0.805
#   f1                  0.555
#   confusion matrix:
#   [[   915    230]
#    [    41    169]]
#
# label: thrash
#   balanced_accuracy   0.749
#   precision           0.382
#   recall              0.741
#   f1                  0.504
#   confusion matrix:
#   [[   854    273]
#    [    59    169]]
#
# Average binary classification scores:
#   balanced_accuracy   0.76 +/- 0.08
#   precision           0.47 +/- 0.14
#   recall              0.75 +/- 0.09
#   f1                  0.57 +/- 0.09
#
# Multi-label classification metrics:
#   accuracy      0.43
#   precision     0.49
#   recall        0.76
#   f1            0.59
#   hamming loss  0.96
#
# ROC AUC scores:
#   black     : 0.859
#   death     : 0.779
#   power     : 0.884
#   thrash    : 0.819
#   macro-avg : 0.835 +/- 0.040

# %%
print(multinomial_mlc.threshold)
multinomial_pipeline.fit(X, y, labels=genres)
multinomial_pipeline.set_threshold(multinomial_mlc.threshold)

for text in test_corpus:
    print(text)
    multinomial_pipeline.classify_text(text)
    print()
# Out:
# [0.27942283 0.36933013 0.23301521 0.21592284]
# 100%|███████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 783.78it/s]
# Classification:
# NONE
#
# Individual label probabilities:
# death      35%
# black      24%
# thrash     19%
# power      18%
#
# satan
# Classification:
# BLACK, THRASH
#
# Individual label probabilities:
# black      54%
# death      34%
# thrash     26%
# power       7%
#
# flesh
# Classification:
# DEATH, BLACK
#
# Individual label probabilities:
# death      55%
# black      31%
# thrash     17%
# power       6%
#
# fight
# Classification:
# POWER, THRASH
#
# Individual label probabilities:
# power      32%
# death      22%
# thrash     22%
# black      14%
#
# attack
# Classification:
# THRASH
#
# Individual label probabilities:
# thrash     36%
# death      33%
# black      23%
# power      18%

# %% [markdown]
# ### Feature importances

# %%
for genre, clf in zip(genres, multinomial_pipeline.classifier.classifiers_):
    print(genre)
    fi = clf.coef_[0]
    fi_top = fi.argsort()[-10:]
    x_vals = range(len(fi_top))
    plt.bar(x_vals, fi[fi_top])
    plt.xticks(x_vals, np.array(multinomial_pipeline.vocabulary)[fi_top], rotation=45)
    plt.show()
# Out:
# black
# death
# power
# thrash

# %% [markdown]
# <a id='complementnb'></a>
# ### Complement multinomial Naive Bayes

# %%
pipeline = Pipeline(
    vectorizer=TfidfVectorizer(stop_words=stopwords, max_features=3000),
    resampler=MLSOL(perc_gen_instances=0.3, k=5),
    classifier=BinaryRelevance(
        ComplementNB(),
        require_dense=[False, True]
    )
)
mlc, _ = multilabel_pipeline_cross_val(pipeline, X, y, labels=genres)
mlc.print_report()
best_thresh = mlc.thresh
if isinstance(best_thresh, float):
    best_thresh = np.ones(mlc.n_labels) * best_thresh
if len(best_thresh.shape) == 2:
    best_thresh = best_thresh.mean(0)
print("\nDecision thresholds:")
for i, label in enumerate(mlc.labels):
    print(f"  {label:<10s}: {best_thresh[i]:.2f}")
mlc.plot_roc_curve()
plt.show()
mlc.plot_precision_recall_curve()
plt.show()
# Out:
# fold 1/3
# C:\Users\philippe\Anaconda3\envs\metallyrics\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['insermi'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# fold 2/3
# fold 3/3
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.717
#   precision           0.451
#   recall              0.575
#   f1                  0.506
#   confusion matrix:
#   [[ 41641   6805]
#    [  4133   5595]]
#
# label: death
#   balanced_accuracy   0.686
#   precision           0.511
#   recall              0.740
#   f1                  0.605
#   confusion matrix:
#   [[ 24177  14086]
#    [  5171  14740]]
#
# label: heavy
#   balanced_accuracy   0.500
#   precision           0.667
#   recall              0.000
#   f1                  0.000
#   confusion matrix:
#   [[ 48574      1]
#    [  9597      2]]
#
# label: power
#   balanced_accuracy   0.719
#   precision           0.444
#   recall              0.638
#   f1                  0.524
#   confusion matrix:
#   [[ 37119   9344]
#    [  4236   7475]]
#
# label: thrash
#   balanced_accuracy   0.651
#   precision           0.326
#   recall              0.544
#   f1                  0.408
#   confusion matrix:
#   [[ 36304  11565]
#    [  4701   5604]]
#
# Average binary classification scores:
#   balanced_accuracy   0.65 +/- 0.16
#   precision           0.48 +/- 0.22
#   recall              0.50 +/- 0.52
#   f1                  0.41 +/- 0.43
#
# Multi-label classification metrics:
#   accuracy      0.37
#   precision     0.45
#   recall        0.57
#   f1            0.50
#   hamming loss  1.20
#
# ROC AUC scores:
#   black     : 0.812
#   death     : 0.758
#   heavy     : 0.789
#   power     : 0.802
#   thrash    : 0.717
#   macro-avg : 0.776 +/- 0.034
#
# Decision thresholds:
#   black     : 0.61
#   death     : 0.46
#   heavy     : 0.98
#   power     : 0.57
#   thrash    : 0.54

# %% [markdown]
# <a id='bernoullinb'></a>
# ### Bernoulli Naive Bayes

# %%
bernoulli_pipeline = NLPipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5, random_state=0),
    classifier=BinaryRelevance(
        BernoulliNB(alpha=1.0),
        require_dense=[False, True]
    )
)
bernoulli_mlc = multilabel_pipeline_cross_val(bernoulli_pipeline, X, y, labels=genres, verbose=2)
bernoulli_mlc.plot_roc_curve()
plt.show()
bernoulli_mlc.plot_precision_recall_curve()
plt.show()
# Out:
# --------
# Fold 1/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 909.09it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.681
#   precision           0.357
#   recall              0.833
#   f1                  0.500
#   confusion matrix:
#   [[   182    162]
#    [    18     90]]
#
# label: death
#   balanced_accuracy   0.636
#   precision           0.540
#   recall              0.484
#   f1                  0.510
#   confusion matrix:
#   [[   236     63]
#    [    79     74]]
#
# label: power
#   balanced_accuracy   0.659
#   precision           0.306
#   recall              0.543
#   f1                  0.392
#   confusion matrix:
#   [[   296     86]
#    [    32     38]]
#
# label: thrash
#   balanced_accuracy   0.538
#   precision           0.203
#   recall              0.368
#   f1                  0.262
#   confusion matrix:
#   [[   266    110]
#    [    48     28]]
#
# Average binary classification scores:
#   balanced_accuracy   0.63 +/- 0.11
#   precision           0.35 +/- 0.24
#   recall              0.56 +/- 0.34
#   f1                  0.42 +/- 0.20
#
# Multi-label classification metrics:
#   accuracy      0.31
#   precision     0.36
#   recall        0.58
#   f1            0.44
#   hamming loss  1.32
#
# ROC AUC scores:
#   black     : 0.715
#   death     : 0.700
#   power     : 0.771
#   thrash    : 0.611
#   macro-avg : 0.699 +/- 0.057
#
# --------
# Fold 2/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 912.37it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.717
#   precision           0.399
#   recall              0.824
#   f1                  0.538
#   confusion matrix:
#   [[   209    134]
#    [    19     89]]
#
# label: death
#   balanced_accuracy   0.654
#   precision           0.556
#   recall              0.523
#   f1                  0.539
#   confusion matrix:
#   [[   234     64]
#    [    73     80]]
#
# label: power
#   balanced_accuracy   0.662
#   precision           0.305
#   recall              0.557
#   f1                  0.394
#   confusion matrix:
#   [[   292     89]
#    [    31     39]]
#
# label: thrash
#   balanced_accuracy   0.561
#   precision           0.227
#   recall              0.395
#   f1                  0.288
#   confusion matrix:
#   [[   273    102]
#    [    46     30]]
#
# Average binary classification scores:
#   balanced_accuracy   0.65 +/- 0.11
#   precision           0.37 +/- 0.24
#   recall              0.57 +/- 0.31
#   f1                  0.44 +/- 0.21
#
# Multi-label classification metrics:
#   accuracy      0.32
#   precision     0.38
#   recall        0.60
#   f1            0.47
#   hamming loss  1.24
#
# ROC AUC scores:
#   black     : 0.779
#   death     : 0.732
#   power     : 0.742
#   thrash    : 0.656
#   macro-avg : 0.727 +/- 0.045
#
# --------
# Fold 3/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 902.92it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.674
#   precision           0.371
#   recall              0.752
#   f1                  0.497
#   confusion matrix:
#   [[   204    139]
#    [    27     82]]
#
# label: death
#   balanced_accuracy   0.721
#   precision           0.611
#   recall              0.651
#   f1                  0.631
#   confusion matrix:
#   [[   237     63]
#    [    53     99]]
#
# label: power
#   balanced_accuracy   0.702
#   precision           0.350
#   recall              0.614
#   f1                  0.446
#   confusion matrix:
#   [[   302     80]
#    [    27     43]]
#
# label: thrash
#   balanced_accuracy   0.572
#   precision           0.230
#   recall              0.447
#   f1                  0.304
#   confusion matrix:
#   [[   262    114]
#    [    42     34]]
#
# Average binary classification scores:
#   balanced_accuracy   0.67 +/- 0.11
#   precision           0.39 +/- 0.28
#   recall              0.62 +/- 0.22
#   f1                  0.47 +/- 0.23
#
# Multi-label classification metrics:
#   accuracy      0.35
#   precision     0.40
#   recall        0.64
#   f1            0.49
#   hamming loss  1.21
#
# ROC AUC scores:
#   black     : 0.702
#   death     : 0.815
#   power     : 0.768
#   thrash    : 0.616
#   macro-avg : 0.725 +/- 0.074
#
# ------------------------
# Cross-validation results
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.707
#   precision           0.401
#   recall              0.782
#   f1                  0.530
#   confusion matrix:
#   [[   651    379]
#    [    71    254]]
#
# label: death
#   balanced_accuracy   0.680
#   precision           0.551
#   recall              0.618
#   f1                  0.582
#   confusion matrix:
#   [[   666    231]
#    [   175    283]]
#
# label: power
#   balanced_accuracy   0.710
#   precision           0.312
#   recall              0.705
#   f1                  0.433
#   confusion matrix:
#   [[   819    326]
#    [    62    148]]
#
# label: thrash
#   balanced_accuracy   0.577
#   precision           0.215
#   recall              0.592
#   f1                  0.315
#   confusion matrix:
#   [[   634    493]
#    [    93    135]]
#
# Average binary classification scores:
#   balanced_accuracy   0.67 +/- 0.11
#   precision           0.37 +/- 0.25
#   recall              0.67 +/- 0.15
#   f1                  0.47 +/- 0.20
#
# Multi-label classification metrics:
#   accuracy      0.34
#   precision     0.37
#   recall        0.68
#   f1            0.48
#   hamming loss  1.35
#
# ROC AUC scores:
#   black     : 0.730
#   death     : 0.743
#   power     : 0.760
#   thrash    : 0.626
#   macro-avg : 0.715 +/- 0.052

# %%
print(bernoulli_mlc.threshold)
bernoulli_pipeline.fit(X, y, labels=genres)
bernoulli_pipeline.set_threshold(bernoulli_mlc.threshold)

for text in test_corpus:
    print(text)
    bernoulli_pipeline.classify_text(text)
    print()
# Out:
# [9.99999509e-01 1.09354249e-02 6.28158439e-17 6.47363821e-19]
# 100%|███████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 828.57it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-0f66836c4283> in <module>
#       1 print(bernoulli_mlc.threshold)
#       2 bernoulli_pipeline.fit(X, y, labels=genres)
# ----> 3 bernoulli_pipeline.set_thresholds(bernoulli_mlc.threshold)
#       4
#       5 for text in test_corpus:
#
# AttributeError: 'NLPipeline' object has no attribute 'set_thresholds'

# %% [markdown]
# ### Feature importances

# %%
for genre, clf in zip(genres, bernoulli_pipeline.classifier.classifiers_):
    print(genre)
    fi = clf.coef_[0]
    fi_top = fi.argsort()[-10:]
    x_vals = range(len(fi_top))
    plt.bar(x_vals, fi[fi_top])
    plt.xticks(x_vals, np.array(bernoulli_pipeline.vocabulary)[fi_top], rotation=45)
    plt.show()

# %% [markdown]
# <a id='rf'></a>
# # Random forest classifier
#
# The random forest classifier is a popular choice in classification problems, especially when overfitting is a concern. As an ensemble model, the random forest does a good job of minimizing bias by averaging out the contributions of many hundreds or thousands of predictors.

# %%
rf_params = dict(
    n_estimators=1000,
    max_features='auto',
    bootstrap=True,
    n_jobs=-1,
    random_state=0
)
rf_pipeline = NLPipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5, random_state=0),
    classifier=BinaryRelevance(
        RandomForestClassifier(**rf_params),
        require_dense=[False, True]
    )
)
rf_mlc = multilabel_pipeline_cross_val(rf_pipeline, X, y, labels=genres, verbose=2)
rf_mlc.plot_roc_curve()
plt.show()
rf_mlc.plot_precision_recall_curve()
plt.show()
# Out:
# --------
# Fold 1/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 899.99it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.634
#   precision           0.680
#   recall              0.315
#   f1                  0.430
#   confusion matrix:
#   [[   328     16]
#    [    74     34]]
#
# label: death
#   balanced_accuracy   0.656
#   precision           0.714
#   recall              0.392
#   f1                  0.506
#   confusion matrix:
#   [[   275     24]
#    [    93     60]]
#
# label: power
#   balanced_accuracy   0.586
#   precision           1.000
#   recall              0.171
#   f1                  0.293
#   confusion matrix:
#   [[   382      0]
#    [    58     12]]
#
# label: thrash
#   balanced_accuracy   0.512
#   precision           0.667
#   recall              0.026
#   f1                  0.051
#   confusion matrix:
#   [[   375      1]
#    [    74      2]]
#
# Average binary classification scores:
#   balanced_accuracy   0.60 +/- 0.11
#   precision           0.77 +/- 0.27
#   recall              0.23 +/- 0.28
#   f1                  0.32 +/- 0.35
#
# Multi-label classification metrics:
#   accuracy      0.25
#   precision     0.74
#   recall        0.28
#   f1            0.40
#   hamming loss  0.75
#
# ROC AUC scores:
#   black     : 0.898
#   death     : 0.797
#   power     : 0.918
#   thrash    : 0.841
#   macro-avg : 0.864 +/- 0.047
#
# --------
# Fold 2/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 899.91it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.678
#   precision           0.837
#   recall              0.380
#   f1                  0.522
#   confusion matrix:
#   [[   336      8]
#    [    67     41]]
#
# label: death
#   balanced_accuracy   0.672
#   precision           0.800
#   recall              0.395
#   f1                  0.529
#   confusion matrix:
#   [[   285     15]
#    [    92     60]]
#
# label: power
#   balanced_accuracy   0.549
#   precision           0.875
#   recall              0.100
#   f1                  0.179
#   confusion matrix:
#   [[   381      1]
#    [    63      7]]
#
# label: thrash
#   balanced_accuracy   0.520
#   precision           1.000
#   recall              0.039
#   f1                  0.076
#   confusion matrix:
#   [[   376      0]
#    [    73      3]]
#
# Average binary classification scores:
#   balanced_accuracy   0.60 +/- 0.14
#   precision           0.88 +/- 0.15
#   recall              0.23 +/- 0.32
#   f1                  0.33 +/- 0.40
#
# Multi-label classification metrics:
#   accuracy      0.28
#   precision     0.83
#   recall        0.29
#   f1            0.43
#   hamming loss  0.71
#
# ROC AUC scores:
#   black     : 0.888
#   death     : 0.835
#   power     : 0.905
#   thrash    : 0.863
#   macro-avg : 0.873 +/- 0.027
#
# --------
# Fold 3/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 921.76it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.633
#   precision           0.680
#   recall              0.312
#   f1                  0.428
#   confusion matrix:
#   [[   326     16]
#    [    75     34]]
#
# label: death
#   balanced_accuracy   0.651
#   precision           0.803
#   recall              0.346
#   f1                  0.484
#   confusion matrix:
#   [[   285     13]
#    [   100     53]]
#
# label: power
#   balanced_accuracy   0.560
#   precision           0.750
#   recall              0.129
#   f1                  0.220
#   confusion matrix:
#   [[   378      3]
#    [    61      9]]
#
# label: thrash
#   balanced_accuracy   0.518
#   precision           0.750
#   recall              0.039
#   f1                  0.075
#   confusion matrix:
#   [[   374      1]
#    [    73      3]]
#
# Average binary classification scores:
#   balanced_accuracy   0.59 +/- 0.11
#   precision           0.75 +/- 0.09
#   recall              0.21 +/- 0.25
#   f1                  0.30 +/- 0.33
#
# Multi-label classification metrics:
#   accuracy      0.25
#   precision     0.76
#   recall        0.27
#   f1            0.40
#   hamming loss  0.76
#
# ROC AUC scores:
#   black     : 0.849
#   death     : 0.811
#   power     : 0.900
#   thrash    : 0.834
#   macro-avg : 0.849 +/- 0.032
#
# ------------------------
# Cross-validation results
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.805
#   precision           0.545
#   recall              0.828
#   f1                  0.657
#   confusion matrix:
#   [[   805    225]
#    [    56    269]]
#
# label: death
#   balanced_accuracy   0.719
#   precision           0.578
#   recall              0.699
#   f1                  0.632
#   confusion matrix:
#   [[   663    234]
#    [   138    320]]
#
# label: power
#   balanced_accuracy   0.831
#   precision           0.417
#   recall              0.890
#   f1                  0.568
#   confusion matrix:
#   [[   884    261]
#    [    23    187]]
#
# label: thrash
#   balanced_accuracy   0.778
#   precision           0.419
#   recall              0.772
#   f1                  0.543
#   confusion matrix:
#   [[   883    244]
#    [    52    176]]
#
# Average binary classification scores:
#   balanced_accuracy   0.78 +/- 0.08
#   precision           0.49 +/- 0.14
#   recall              0.80 +/- 0.14
#   f1                  0.60 +/- 0.09
#
# Multi-label classification metrics:
#   accuracy      0.47
#   precision     0.52
#   recall        0.80
#   f1            0.63
#   hamming loss  0.91
#
# ROC AUC scores:
#   black     : 0.878
#   death     : 0.814
#   power     : 0.907
#   thrash    : 0.846
#   macro-avg : 0.862 +/- 0.035

# %%
print(rf_mlc.threshold)
rf_pipeline.fit(X, y, labels=genres)
rf_pipeline.set_threshold(rf_mlc.threshold)

for text in test_corpus:
    print(text)
    rf_pipeline.classify_text(text)
    print()
# Out:
# [0.30666667 0.383      0.188      0.22733333]
# 100%|███████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 803.91it/s]
# Classification:
# BLACK
#
# Individual label probabilities:
# black      44%
# thrash     20%
# death       0%
# power       0%
#
# satan
# Classification:
# BLACK
#
# Individual label probabilities:
# black      47%
# thrash     21%
# death       1%
# power       0%
#
# flesh
# Classification:
# BLACK
#
# Individual label probabilities:
# black      44%
# thrash     18%
# death      11%
# power       0%
#
# fight
# Classification:
# BLACK
#
# Individual label probabilities:
# black      43%
# thrash     19%
# power       4%
# death       0%
#
# attack
# Classification:
# BLACK
#
# Individual label probabilities:
# black      44%
# thrash     21%
# death       2%
# power       0%

# %% [markdown]
# ### Feature importances

# %%
for genre, clf in zip(genres, rf_pipeline.classifier.classifiers_):
    print(genre)
    fi = clf.feature_importances_
    fi_top = fi.argsort()[-10:]
    x_vals = range(len(fi_top))
    plt.bar(x_vals, fi[fi_top])
    plt.xticks(x_vals, np.array(rf_pipeline.vocabulary)[fi_top], rotation=45)
    plt.show()
# Out:
# black
# death
# power
# thrash

# %% [markdown]
# <a id='gbm'></a>
# # Gradient boosting model

# %%
gbm_params = dict(
    boosting_type='dart',
    n_estimators=1000,
#     num_leaves=15,
    num_leaves=63,
#     max_bin=511,
#     learning_rate=(1/10.) * 0.1,
#     num_iterations=10 * 100,
    n_jobs=-1,
    random_state=0
)
gbm_pipeline = NLPipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5, random_state=0),
    classifier=BinaryRelevance(
        lgb.LGBMClassifier(**gbm_params),
        require_dense=[False, True]
    )
)
gbm_mlc = multilabel_pipeline_cross_val(gbm_pipeline, X, y, labels=genres, verbose=2)
gbm_mlc.plot_roc_curve()
plt.show()
gbm_mlc.plot_precision_recall_curve()
plt.show()
# Out:
# --------
# Fold 1/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 859.87it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.722
#   precision           0.724
#   recall              0.505
#   f1                  0.595
#   confusion matrix:
#   [[   322     21]
#    [    54     55]]
#
# label: death
#   balanced_accuracy   0.712
#   precision           0.762
#   recall              0.503
#   f1                  0.606
#   confusion matrix:
#   [[   275     24]
#    [    76     77]]
#
# label: power
#   balanced_accuracy   0.673
#   precision           0.722
#   recall              0.371
#   f1                  0.491
#   confusion matrix:
#   [[   372     10]
#    [    44     26]]
#
# label: thrash
#   balanced_accuracy   0.612
#   precision           0.783
#   recall              0.237
#   f1                  0.364
#   confusion matrix:
#   [[   371      5]
#    [    58     18]]
#
# Average binary classification scores:
#   balanced_accuracy   0.68 +/- 0.09
#   precision           0.75 +/- 0.05
#   recall              0.40 +/- 0.22
#   f1                  0.51 +/- 0.20
#
# Multi-label classification metrics:
#   accuracy      0.40
#   precision     0.76
#   recall        0.45
#   f1            0.57
#   hamming loss  0.65
#
# ROC AUC scores:
#   black     : 0.896
#   death     : 0.823
#   power     : 0.919
#   thrash    : 0.816
#   macro-avg : 0.863 +/- 0.045
#
# --------
# Fold 2/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 894.04it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.757
#   precision           0.724
#   recall              0.583
#   f1                  0.646
#   confusion matrix:
#   [[   320     24]
#    [    45     63]]
#
# label: death
#   balanced_accuracy   0.683
#   precision           0.673
#   recall              0.487
#   f1                  0.565
#   confusion matrix:
#   [[   264     36]
#    [    78     74]]
#
# label: power
#   balanced_accuracy   0.699
#   precision           0.829
#   recall              0.414
#   f1                  0.552
#   confusion matrix:
#   [[   376      6]
#    [    41     29]]
#
# label: thrash
#   balanced_accuracy   0.613
#   precision           0.818
#   recall              0.237
#   f1                  0.367
#   confusion matrix:
#   [[   372      4]
#    [    58     18]]
#
# Average binary classification scores:
#   balanced_accuracy   0.69 +/- 0.10
#   precision           0.76 +/- 0.13
#   recall              0.43 +/- 0.25
#   f1                  0.53 +/- 0.20
#
# Multi-label classification metrics:
#   accuracy      0.42
#   precision     0.74
#   recall        0.48
#   f1            0.59
#   hamming loss  0.65
#
# ROC AUC scores:
#   black     : 0.893
#   death     : 0.791
#   power     : 0.929
#   thrash    : 0.865
#   macro-avg : 0.869 +/- 0.051
#
# --------
# Fold 3/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 921.77it/s]
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.716
#   precision           0.754
#   recall              0.481
#   f1                  0.588
#   confusion matrix:
#   [[   326     17]
#    [    56     52]]
#
# label: death
#   balanced_accuracy   0.681
#   precision           0.673
#   recall              0.484
#   f1                  0.563
#   confusion matrix:
#   [[   262     36]
#    [    79     74]]
#
# label: power
#   balanced_accuracy   0.728
#   precision           0.846
#   recall              0.471
#   f1                  0.606
#   confusion matrix:
#   [[   375      6]
#    [    37     33]]
#
# label: thrash
#   balanced_accuracy   0.642
#   precision           0.767
#   recall              0.303
#   f1                  0.434
#   confusion matrix:
#   [[   368      7]
#    [    53     23]]
#
# Average binary classification scores:
#   balanced_accuracy   0.69 +/- 0.07
#   precision           0.76 +/- 0.12
#   recall              0.43 +/- 0.15
#   f1                  0.55 +/- 0.13
#
# Multi-label classification metrics:
#   accuracy      0.42
#   precision     0.75
#   recall        0.47
#   f1            0.58
#   hamming loss  0.65
#
# ROC AUC scores:
#   black     : 0.888
#   death     : 0.811
#   power     : 0.903
#   thrash    : 0.855
#   macro-avg : 0.864 +/- 0.035
#
# ------------------------
# Cross-validation results
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.811
#   precision           0.570
#   recall              0.815
#   f1                  0.671
#   confusion matrix:
#   [[   830    200]
#    [    60    265]]
#
# label: death
#   balanced_accuracy   0.726
#   precision           0.586
#   recall              0.707
#   f1                  0.641
#   confusion matrix:
#   [[   668    229]
#    [   134    324]]
#
# label: power
#   balanced_accuracy   0.842
#   precision           0.528
#   recall              0.819
#   f1                  0.642
#   confusion matrix:
#   [[   991    154]
#    [    38    172]]
#
# label: thrash
#   balanced_accuracy   0.771
#   precision           0.384
#   recall              0.803
#   f1                  0.520
#   confusion matrix:
#   [[   834    293]
#    [    45    183]]
#
# Average binary classification scores:
#   balanced_accuracy   0.79 +/- 0.09
#   precision           0.52 +/- 0.16
#   recall              0.79 +/- 0.09
#   f1                  0.62 +/- 0.12
#
# Multi-label classification metrics:
#   accuracy      0.48
#   precision     0.54
#   recall        0.79
#   f1            0.64
#   hamming loss  0.85
#
# ROC AUC scores:
#   black     : 0.892
#   death     : 0.807
#   power     : 0.917
#   thrash    : 0.846
#   macro-avg : 0.866 +/- 0.042

# %%
print(gbm_mlc.threshold)
gbm_pipeline.fit(X, y, labels=genres)

gbm_pipeline.set_threshold(gbm_mlc.threshold)

for text in test_corpus:
    print(text)
    gbm_pipeline.classify_text(text)
    print()
# Out:
# [0.01066979 0.04560407 0.00198323 0.00055241]
# 100%|███████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 856.54it/s]
# Classification:
# BLACK
#
# Individual label probabilities:
# black      33%
# thrash      0%
# death       0%
# power       0%
#
# satan
# Classification:
# BLACK
#
# Individual label probabilities:
# black      99%
# thrash      0%
# death       0%
# power       0%
#
# flesh
# Classification:
# BLACK
#
# Individual label probabilities:
# black      33%
# death       0%
# thrash      0%
# power       0%
#
# fight
# Classification:
# BLACK
#
# Individual label probabilities:
# black      23%
# thrash      0%
# power       0%
# death       0%
#
# attack
# Classification:
# BLACK
#
# Individual label probabilities:
# black      30%
# thrash      0%
# death       0%
# power       0%

# %% [markdown]
# ### Feature importances

# %%
for genre, clf in zip(genres, gbm_pipeline.classifier.classifiers_):
    print(genre)
    fi = clf.feature_importances_
    fi_top = fi.argsort()[-10:]
    x_vals = range(len(fi_top))
    plt.bar(x_vals, fi[fi_top])
    plt.xticks(x_vals, np.array(gbm_pipeline.vectorizer.get_feature_names())[fi_top], rotation=45)
    plt.show()
# Out:
# black
# death
# power
# thrash

# %% [markdown]
# <a id='nn'></a>
# # Neural network

# %%
def create_keras_model(input_dim):
    model = Sequential()
    model.add(layers.Dense(64, input_dim=input_dim, activation='relu'))
    model.add(layers.Dropout(rate=0.2))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])
    return model

# def keras_batch_generator(X_data, y_data, batch_size):
#     number_of_batches = X_data.shape[0] // batch_size
#     counter = 0
#     index = np.arange(np.shape(y_data)[0])
#     while 1:
#         index_batch = index[batch_size * counter:batch_size * (counter + 1)]
#         X_batch = X_data[index_batch, :].todense()
#         y_batch = y_data[index_batch]
#         counter += 1
#         yield np.array(X_batch), y_batch
#         if counter > number_of_batches:
#             counter = 0

# %% [markdown]
# Best so far: 64 epochs, 128 batches, hidden layer of 256 nodes.
#
# Low epochs underfits. 128 epochs works too, but not really worth.
#
# Low batch size kind of underfits?
#
# More hidden layer nodes overfits. Fewer kind of underfits.

# %%
keras_params = dict(
    input_dim=vectorizer.max_features,
    epochs=64,
    batch_size=128,
)

keras_pipeline = NLPipeline(
    vectorizer=vectorizer,
    resampler=MLSOL(perc_gen_instances=0.3, k=5, random_state=0),
    classifier=BinaryRelevance(
        KerasClassifier(create_keras_model, **keras_params),
        require_dense=[False, True]
    ),
    pad_features=True,
)
keras_mlc = multilabel_pipeline_cross_val(keras_pipeline, X, y, labels=genres, verbose=2)
keras_mlc.plot_roc_curve()
plt.show()
keras_mlc.plot_precision_recall_curve()
plt.show()
# Out:
# --------
# Fold 1/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 270/270 [00:00<00:00, 915.16it/s]
# Epoch 1/64
# 1173/1173 [==============================] - 1s 1ms/step - loss: 0.6532 - binary_accuracy: 0.7067
# Epoch 2/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.5463 - binary_accuracy: 0.7468
# Epoch 3/64
# 1173/1173 [==============================] - 0s 43us/step - loss: 0.4956 - binary_accuracy: 0.7468
# Epoch 4/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.4463 - binary_accuracy: 0.7698
# Epoch 5/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.3995 - binary_accuracy: 0.8005
# Epoch 6/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.3543 - binary_accuracy: 0.8465
# Epoch 7/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.3236 - binary_accuracy: 0.8602
# Epoch 8/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.2992 - binary_accuracy: 0.8781
# Epoch 9/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.2789 - binary_accuracy: 0.8824
# Epoch 10/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.2471 - binary_accuracy: 0.9088
# Epoch 11/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.2160 - binary_accuracy: 0.9190
# Epoch 12/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1875 - binary_accuracy: 0.9352
# Epoch 13/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1658 - binary_accuracy: 0.9412
# Epoch 14/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.1492 - binary_accuracy: 0.9471
# Epoch 15/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.1372 - binary_accuracy: 0.9497
# Epoch 16/64
# 1173/1173 [==============================] - 0s 40us/step - loss: 0.1104 - binary_accuracy: 0.9693
# Epoch 17/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.1043 - binary_accuracy: 0.9659
# Epoch 18/64
# 1173/1173 [==============================] - 0s 32us/step - loss: 0.0859 - binary_accuracy: 0.9753
# Epoch 19/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0697 - binary_accuracy: 0.9778
# Epoch 20/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0660 - binary_accuracy: 0.9847
# Epoch 21/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0529 - binary_accuracy: 0.9847
# Epoch 22/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0486 - binary_accuracy: 0.9864
# Epoch 23/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0419 - binary_accuracy: 0.9932
# Epoch 24/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0391 - binary_accuracy: 0.9889
# Epoch 25/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0284 - binary_accuracy: 0.9974
# Epoch 26/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0273 - binary_accuracy: 0.9923
# Epoch 27/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0218 - binary_accuracy: 0.9957
# Epoch 28/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0193 - binary_accuracy: 0.9983
# Epoch 29/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0206 - binary_accuracy: 0.9940
# Epoch 30/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0230 - binary_accuracy: 0.9940
# Epoch 31/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0179 - binary_accuracy: 0.9957
# Epoch 32/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0148 - binary_accuracy: 0.9974
# Epoch 33/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0119 - binary_accuracy: 0.9991
# Epoch 34/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0092 - binary_accuracy: 0.9991
# Epoch 35/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0087 - binary_accuracy: 1.0000
# Epoch 36/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0073 - binary_accuracy: 1.0000
# Epoch 37/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0072 - binary_accuracy: 0.9991
# Epoch 38/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0070 - binary_accuracy: 0.9991
# Epoch 39/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0085 - binary_accuracy: 0.9974
# Epoch 40/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0079 - binary_accuracy: 0.9991
# Epoch 41/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0069 - binary_accuracy: 0.9991
# Epoch 42/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0067 - binary_accuracy: 1.0000
# Epoch 43/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0056 - binary_accuracy: 0.9991
# Epoch 44/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0043 - binary_accuracy: 1.0000
# Epoch 45/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0045 - binary_accuracy: 1.0000
# Epoch 46/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0051 - binary_accuracy: 1.0000
# Epoch 47/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0055 - binary_accuracy: 0.9991
# Epoch 48/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0041 - binary_accuracy: 0.9991
# Epoch 49/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 50/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 51/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0035 - binary_accuracy: 0.9991
# Epoch 52/64
# 1173/1173 [==============================] - 0s 41us/step - loss: 0.0024 - binary_accuracy: 1.0000
# Epoch 53/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 54/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 55/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 56/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 57/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 58/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0023 - binary_accuracy: 0.9991
# Epoch 59/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 60/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 61/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 62/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 63/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0016 - binary_accuracy: 1.0000
# Epoch 64/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 1/64
# 1173/1173 [==============================] - 1s 1ms/step - loss: 0.6705 - binary_accuracy: 0.6377
# Epoch 2/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.6314 - binary_accuracy: 0.6505
# Epoch 3/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.5996 - binary_accuracy: 0.6530
# Epoch 4/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.5636 - binary_accuracy: 0.7016
# Epoch 5/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.5207 - binary_accuracy: 0.7477
# Epoch 6/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.4841 - binary_accuracy: 0.7681
# Epoch 7/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.4549 - binary_accuracy: 0.7920
# Epoch 8/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.4438 - binary_accuracy: 0.7928
# Epoch 9/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.3943 - binary_accuracy: 0.8227
# Epoch 10/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.3609 - binary_accuracy: 0.8551
# Epoch 11/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.3315 - binary_accuracy: 0.8721
# Epoch 12/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.2899 - binary_accuracy: 0.8909
# Epoch 13/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.2737 - binary_accuracy: 0.8883
# Epoch 14/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.2360 - binary_accuracy: 0.9147
# Epoch 15/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.2056 - binary_accuracy: 0.9292
# Epoch 16/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1855 - binary_accuracy: 0.9386
# Epoch 17/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.1636 - binary_accuracy: 0.9497
# Epoch 18/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1378 - binary_accuracy: 0.9540
# Epoch 19/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1172 - binary_accuracy: 0.9642
# Epoch 20/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.1021 - binary_accuracy: 0.9727
# Epoch 21/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0814 - binary_accuracy: 0.9829
# Epoch 22/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0676 - binary_accuracy: 0.9787
# Epoch 23/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0667 - binary_accuracy: 0.9838
# Epoch 24/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0500 - binary_accuracy: 0.9949
# Epoch 25/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0451 - binary_accuracy: 0.9915
# Epoch 26/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0393 - binary_accuracy: 0.9957
# Epoch 27/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0312 - binary_accuracy: 0.9966
# Epoch 28/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0288 - binary_accuracy: 0.9974
# Epoch 29/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0241 - binary_accuracy: 0.9983
# Epoch 30/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0248 - binary_accuracy: 0.9974
# Epoch 31/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0180 - binary_accuracy: 0.9983
# Epoch 32/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0153 - binary_accuracy: 0.9983
# Epoch 33/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0174 - binary_accuracy: 0.9957
# Epoch 34/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0161 - binary_accuracy: 0.9983
# Epoch 35/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0125 - binary_accuracy: 1.0000
# Epoch 36/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0126 - binary_accuracy: 0.9991
# Epoch 37/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0096 - binary_accuracy: 0.9991
# Epoch 38/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0100 - binary_accuracy: 1.0000
# Epoch 39/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0099 - binary_accuracy: 1.0000
# Epoch 40/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0122 - binary_accuracy: 0.9983
# Epoch 41/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0089 - binary_accuracy: 0.9991
# Epoch 42/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0066 - binary_accuracy: 1.0000
# Epoch 43/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0063 - binary_accuracy: 1.0000
# Epoch 44/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0069 - binary_accuracy: 0.9983
# Epoch 45/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0059 - binary_accuracy: 1.0000
# Epoch 46/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0052 - binary_accuracy: 0.9991
# Epoch 47/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0049 - binary_accuracy: 1.0000
# Epoch 48/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0051 - binary_accuracy: 0.9991
# Epoch 49/64
# 1173/1173 [==============================] - 0s 43us/step - loss: 0.0047 - binary_accuracy: 0.9991
# Epoch 50/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0038 - binary_accuracy: 1.0000
# Epoch 51/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0033 - binary_accuracy: 1.0000
# Epoch 52/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0043 - binary_accuracy: 0.9991
# Epoch 53/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0030 - binary_accuracy: 1.0000
# Epoch 54/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0031 - binary_accuracy: 1.0000
# Epoch 55/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 56/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 57/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0024 - binary_accuracy: 1.0000
# Epoch 58/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 59/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 60/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 61/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 62/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 63/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 64/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 1/64
# 1173/1173 [==============================] - 1s 1ms/step - loss: 0.6499 - binary_accuracy: 0.7289
# Epoch 2/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.5122 - binary_accuracy: 0.8210
# Epoch 3/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.4801 - binary_accuracy: 0.8210
# Epoch 4/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.4475 - binary_accuracy: 0.8210
# Epoch 5/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.4060 - binary_accuracy: 0.8210
# Epoch 6/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.3635 - binary_accuracy: 0.8210
# Epoch 7/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.3244 - binary_accuracy: 0.8210
# Epoch 8/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.2969 - binary_accuracy: 0.8210
# Epoch 9/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.2719 - binary_accuracy: 0.8210
# Epoch 10/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.2533 - binary_accuracy: 0.8210
# Epoch 11/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.2365 - binary_accuracy: 0.8210
# Epoch 12/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.2193 - binary_accuracy: 0.8210
# Epoch 13/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.2096 - binary_accuracy: 0.8713
# Epoch 14/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.2010 - binary_accuracy: 0.9156
# Epoch 15/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.1870 - binary_accuracy: 0.9258
# Epoch 16/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1803 - binary_accuracy: 0.9344
# Epoch 17/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1699 - binary_accuracy: 0.9437
# Epoch 18/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.1634 - binary_accuracy: 0.9582
# Epoch 19/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.1536 - binary_accuracy: 0.9625
# Epoch 20/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1460 - binary_accuracy: 0.9685
# Epoch 21/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.1397 - binary_accuracy: 0.9829
# Epoch 22/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1346 - binary_accuracy: 0.9710
# Epoch 23/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.1286 - binary_accuracy: 0.9838
# Epoch 24/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.1210 - binary_accuracy: 0.9932
# Epoch 25/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1157 - binary_accuracy: 0.9940
# Epoch 26/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1096 - binary_accuracy: 0.9957
# Epoch 27/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1025 - binary_accuracy: 0.9966
# Epoch 28/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0957 - binary_accuracy: 0.9983
# Epoch 29/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0896 - binary_accuracy: 0.9983
# Epoch 30/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0798 - binary_accuracy: 0.9991
# Epoch 31/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0678 - binary_accuracy: 1.0000
# Epoch 32/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0534 - binary_accuracy: 1.0000
# Epoch 33/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0388 - binary_accuracy: 1.0000
# Epoch 34/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0285 - binary_accuracy: 0.9991
# Epoch 35/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0225 - binary_accuracy: 0.9991
# Epoch 36/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0179 - binary_accuracy: 0.9991
# Epoch 37/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0148 - binary_accuracy: 1.0000
# Epoch 38/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0147 - binary_accuracy: 0.9991
# Epoch 39/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0104 - binary_accuracy: 0.9991
# Epoch 40/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0084 - binary_accuracy: 0.9991
# Epoch 41/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0078 - binary_accuracy: 1.0000
# Epoch 42/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0058 - binary_accuracy: 1.0000
# Epoch 43/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 44/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0047 - binary_accuracy: 1.0000
# Epoch 45/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0045 - binary_accuracy: 1.0000
# Epoch 46/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0041 - binary_accuracy: 1.0000
# Epoch 47/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0031 - binary_accuracy: 1.0000
# Epoch 48/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 49/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0035 - binary_accuracy: 1.0000
# Epoch 50/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 51/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0023 - binary_accuracy: 1.0000
# Epoch 52/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0036 - binary_accuracy: 1.0000
# Epoch 53/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0041 - binary_accuracy: 0.9991
# Epoch 54/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0035 - binary_accuracy: 1.0000
# Epoch 55/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 56/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0024 - binary_accuracy: 1.0000
# Epoch 57/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 58/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 59/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0016 - binary_accuracy: 1.0000
# Epoch 60/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 61/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 62/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0011 - binary_accuracy: 1.0000
# Epoch 63/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 64/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 1/64
# 1173/1173 [==============================] - 1s 1ms/step - loss: 0.6363 - binary_accuracy: 0.7570
# Epoch 2/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.5093 - binary_accuracy: 0.8065
# Epoch 3/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.4903 - binary_accuracy: 0.8065
# Epoch 4/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.4641 - binary_accuracy: 0.8065
# Epoch 5/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.4440 - binary_accuracy: 0.8065
# Epoch 6/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.4082 - binary_accuracy: 0.8065
# Epoch 7/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.3820 - binary_accuracy: 0.8065
# Epoch 8/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.3587 - binary_accuracy: 0.8065
# Epoch 9/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.3370 - binary_accuracy: 0.8065
# Epoch 10/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.3212 - binary_accuracy: 0.8065
# Epoch 11/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.2970 - binary_accuracy: 0.8116
# Epoch 12/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.2786 - binary_accuracy: 0.8747
# Epoch 13/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.2570 - binary_accuracy: 0.8960
# Epoch 14/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.2358 - binary_accuracy: 0.8968
# Epoch 15/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.2181 - binary_accuracy: 0.9378
# Epoch 16/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1984 - binary_accuracy: 0.9361
# Epoch 17/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1734 - binary_accuracy: 0.9540
# Epoch 18/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1487 - binary_accuracy: 0.9540
# Epoch 19/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.1324 - binary_accuracy: 0.9659
# Epoch 20/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1035 - binary_accuracy: 0.9787
# Epoch 21/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0920 - binary_accuracy: 0.9821
# Epoch 22/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0756 - binary_accuracy: 0.9829
# Epoch 23/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0690 - binary_accuracy: 0.9864
# Epoch 24/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0569 - binary_accuracy: 0.9889
# Epoch 25/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0502 - binary_accuracy: 0.9940
# Epoch 26/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0440 - binary_accuracy: 0.9940
# Epoch 27/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0395 - binary_accuracy: 0.9915
# Epoch 28/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0339 - binary_accuracy: 0.9940
# Epoch 29/64
# 1173/1173 [==============================] - 0s 40us/step - loss: 0.0263 - binary_accuracy: 0.9974
# Epoch 30/64
# 1173/1173 [==============================] - 0s 41us/step - loss: 0.0264 - binary_accuracy: 0.9957
# Epoch 31/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0262 - binary_accuracy: 0.9957
# Epoch 32/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0245 - binary_accuracy: 0.9957
# Epoch 33/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0157 - binary_accuracy: 0.9991
# Epoch 34/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0133 - binary_accuracy: 0.9991
# Epoch 35/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0140 - binary_accuracy: 0.9983
# Epoch 36/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0116 - binary_accuracy: 0.9991
# Epoch 37/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0095 - binary_accuracy: 1.0000
# Epoch 38/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0073 - binary_accuracy: 1.0000
# Epoch 39/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0093 - binary_accuracy: 1.0000
# Epoch 40/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0079 - binary_accuracy: 0.9991
# Epoch 41/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0065 - binary_accuracy: 0.9991
# Epoch 42/64
# 1173/1173 [==============================] - 0s 33us/step - loss: 0.0057 - binary_accuracy: 1.0000
# Epoch 43/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0056 - binary_accuracy: 1.0000
# Epoch 44/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0047 - binary_accuracy: 1.0000
# Epoch 45/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0050 - binary_accuracy: 0.9991
# Epoch 46/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0050 - binary_accuracy: 1.0000
# Epoch 47/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 48/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0040 - binary_accuracy: 0.9991
# Epoch 49/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0028 - binary_accuracy: 1.0000
# Epoch 50/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 51/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0031 - binary_accuracy: 0.9991
# Epoch 52/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 53/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0031 - binary_accuracy: 1.0000
# Epoch 54/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 55/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 56/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 57/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 58/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 59/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 60/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0023 - binary_accuracy: 1.0000
# Epoch 61/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 62/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0010 - binary_accuracy: 1.0000
# Epoch 63/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 7.9682e-04 - binary_accuracy: 1.0000
# Epoch 64/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0010 - binary_accuracy: 1.0000
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.739
#   precision           0.636
#   recall              0.583
#   f1                  0.609
#   confusion matrix:
#   [[   308     36]
#    [    45     63]]
#
# label: death
#   balanced_accuracy   0.693
#   precision           0.634
#   recall              0.546
#   f1                  0.587
#   confusion matrix:
#   [[   252     48]
#    [    69     83]]
#
# label: power
#   balanced_accuracy   0.790
#   precision           0.652
#   recall              0.643
#   f1                  0.647
#   confusion matrix:
#   [[   358     24]
#    [    25     45]]
#
# label: thrash
#   balanced_accuracy   0.714
#   precision           0.679
#   recall              0.474
#   f1                  0.558
#   confusion matrix:
#   [[   359     17]
#    [    40     36]]
#
# Average binary classification scores:
#   balanced_accuracy   0.73 +/- 0.07
#   precision           0.65 +/- 0.04
#   recall              0.56 +/- 0.12
#   f1                  0.60 +/- 0.07
#
# Multi-label classification metrics:
#   accuracy      0.48
#   precision     0.67
#   recall        0.58
#   f1            0.62
#   hamming loss  0.67
#
# ROC AUC scores:
#   black     : 0.865
#   death     : 0.751
#   power     : 0.908
#   thrash    : 0.828
#   macro-avg : 0.838 +/- 0.058
#
# --------
# Fold 2/3
# 100%|███████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 909.31it/s]
# Epoch 1/64
# 1175/1175 [==============================] - 1s 1ms/step - loss: 0.6423 - binary_accuracy: 0.7506
# Epoch 2/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.5175 - binary_accuracy: 0.7540
# Epoch 3/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.4721 - binary_accuracy: 0.7540
# Epoch 4/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.4254 - binary_accuracy: 0.7557
# Epoch 5/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.3815 - binary_accuracy: 0.8136
# Epoch 6/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.3472 - binary_accuracy: 0.8570
# Epoch 7/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.3184 - binary_accuracy: 0.8655
# Epoch 8/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.2962 - binary_accuracy: 0.8774
# Epoch 9/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.2670 - binary_accuracy: 0.8911
# Epoch 10/64
# 1175/1175 [==============================] - 0s 31us/step - loss: 0.2389 - binary_accuracy: 0.9030
# Epoch 11/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.2131 - binary_accuracy: 0.9140
# Epoch 12/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.1767 - binary_accuracy: 0.9387
# Epoch 13/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.1678 - binary_accuracy: 0.9421
# Epoch 14/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.1383 - binary_accuracy: 0.9515
# Epoch 15/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.1246 - binary_accuracy: 0.9574
# Epoch 16/64
# 1175/1175 [==============================] - 0s 31us/step - loss: 0.1109 - binary_accuracy: 0.9634
# Epoch 17/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0849 - binary_accuracy: 0.9711
# Epoch 18/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0687 - binary_accuracy: 0.9830
# Epoch 19/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0571 - binary_accuracy: 0.9881
# Epoch 20/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0495 - binary_accuracy: 0.9872
# Epoch 21/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0423 - binary_accuracy: 0.9940
# Epoch 22/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0357 - binary_accuracy: 0.9940
# Epoch 23/64
# 1175/1175 [==============================] - 0s 31us/step - loss: 0.0294 - binary_accuracy: 0.9940
# Epoch 24/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0247 - binary_accuracy: 0.9957
# Epoch 25/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0227 - binary_accuracy: 0.9966
# Epoch 26/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0207 - binary_accuracy: 0.9966
# Epoch 27/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0200 - binary_accuracy: 0.9966
# Epoch 28/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0181 - binary_accuracy: 0.9957
# Epoch 29/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0117 - binary_accuracy: 0.9983
# Epoch 30/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0101 - binary_accuracy: 0.9991
# Epoch 31/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0095 - binary_accuracy: 1.0000
# Epoch 32/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0077 - binary_accuracy: 1.0000
# Epoch 33/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0068 - binary_accuracy: 1.0000
# Epoch 34/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0065 - binary_accuracy: 1.0000
# Epoch 35/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0061 - binary_accuracy: 1.0000
# Epoch 36/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0051 - binary_accuracy: 1.0000
# Epoch 37/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0044 - binary_accuracy: 1.0000
# Epoch 38/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0045 - binary_accuracy: 1.0000
# Epoch 39/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0037 - binary_accuracy: 1.0000
# Epoch 40/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0039 - binary_accuracy: 1.0000
# Epoch 41/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0033 - binary_accuracy: 1.0000
# Epoch 42/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0049 - binary_accuracy: 0.9991
# Epoch 43/64
# 1175/1175 [==============================] - 0s 31us/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 44/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 45/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 46/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0035 - binary_accuracy: 1.0000
# Epoch 47/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 48/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 49/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 50/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 51/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 52/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 53/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 54/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 55/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 56/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0010 - binary_accuracy: 1.0000
# Epoch 57/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 58/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 59/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 9.9772e-04 - binary_accuracy: 1.0000
# Epoch 60/64
# 1175/1175 [==============================] - 0s 31us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 61/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 62/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0037 - binary_accuracy: 0.9991
# Epoch 63/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0039 - binary_accuracy: 1.0000
# Epoch 64/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 1/64
# 1175/1175 [==============================] - 2s 1ms/step - loss: 0.6582 - binary_accuracy: 0.6681
# Epoch 2/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.6119 - binary_accuracy: 0.6672
# Epoch 3/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.5741 - binary_accuracy: 0.6681
# Epoch 4/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.5352 - binary_accuracy: 0.7098
# Epoch 5/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.4994 - binary_accuracy: 0.7702
# Epoch 6/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.4702 - binary_accuracy: 0.7813
# Epoch 7/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.4409 - binary_accuracy: 0.8034
# Epoch 8/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.4094 - binary_accuracy: 0.8196
# Epoch 9/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.3857 - binary_accuracy: 0.8349
# Epoch 10/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.3452 - binary_accuracy: 0.8638
# Epoch 11/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.3092 - binary_accuracy: 0.8757
# Epoch 12/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.2773 - binary_accuracy: 0.8919
# Epoch 13/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.2607 - binary_accuracy: 0.9038
# Epoch 14/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.2228 - binary_accuracy: 0.9277
# Epoch 15/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.1916 - binary_accuracy: 0.9362
# Epoch 16/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.1639 - binary_accuracy: 0.9523
# Epoch 17/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.1550 - binary_accuracy: 0.9498
# Epoch 18/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.1299 - binary_accuracy: 0.9557
# Epoch 19/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.1095 - binary_accuracy: 0.9745
# Epoch 20/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0892 - binary_accuracy: 0.9838
# Epoch 21/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0814 - binary_accuracy: 0.9813
# Epoch 22/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0665 - binary_accuracy: 0.9881
# Epoch 23/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0565 - binary_accuracy: 0.9864
# Epoch 24/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0486 - binary_accuracy: 0.9906
# Epoch 25/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0484 - binary_accuracy: 0.9881
# Epoch 26/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0383 - binary_accuracy: 0.9957
# Epoch 27/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0325 - binary_accuracy: 0.9974
# Epoch 28/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0309 - binary_accuracy: 0.9957
# Epoch 29/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0283 - binary_accuracy: 0.9949
# Epoch 30/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0232 - binary_accuracy: 0.9957
# Epoch 31/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0241 - binary_accuracy: 0.9966
# Epoch 32/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0180 - binary_accuracy: 0.9983
# Epoch 33/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0139 - binary_accuracy: 0.9991
# Epoch 34/64
# 1175/1175 [==============================] - 0s 31us/step - loss: 0.0135 - binary_accuracy: 0.9991
# Epoch 35/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0163 - binary_accuracy: 0.9983
# Epoch 36/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0141 - binary_accuracy: 0.9983
# Epoch 37/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0108 - binary_accuracy: 0.9983
# Epoch 38/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0104 - binary_accuracy: 1.0000
# Epoch 39/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0094 - binary_accuracy: 0.9991
# Epoch 40/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0084 - binary_accuracy: 1.0000
# Epoch 41/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0078 - binary_accuracy: 0.9991
# Epoch 42/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0071 - binary_accuracy: 0.9991
# Epoch 43/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0060 - binary_accuracy: 1.0000
# Epoch 44/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0065 - binary_accuracy: 1.0000
# Epoch 45/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 46/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0057 - binary_accuracy: 1.0000
# Epoch 47/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0047 - binary_accuracy: 1.0000
# Epoch 48/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0053 - binary_accuracy: 1.0000
# Epoch 49/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0050 - binary_accuracy: 1.0000
# Epoch 50/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0045 - binary_accuracy: 1.0000
# Epoch 51/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0037 - binary_accuracy: 1.0000
# Epoch 52/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0042 - binary_accuracy: 1.0000
# Epoch 53/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 54/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0037 - binary_accuracy: 1.0000
# Epoch 55/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0031 - binary_accuracy: 1.0000
# Epoch 56/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 57/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0031 - binary_accuracy: 1.0000
# Epoch 58/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0040 - binary_accuracy: 0.9991
# Epoch 59/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0030 - binary_accuracy: 1.0000
# Epoch 60/64
# 1175/1175 [==============================] - 0s 32us/step - loss: 0.0024 - binary_accuracy: 1.0000
# Epoch 61/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 62/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0024 - binary_accuracy: 1.0000
# Epoch 63/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 64/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 1/64
# 1175/1175 [==============================] - 2s 1ms/step - loss: 0.6226 - binary_accuracy: 0.8043
# Epoch 2/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.5160 - binary_accuracy: 0.8085
# Epoch 3/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.4828 - binary_accuracy: 0.8085
# Epoch 4/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.4416 - binary_accuracy: 0.8085
# Epoch 5/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.3959 - binary_accuracy: 0.8085
# Epoch 6/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.3470 - binary_accuracy: 0.8085
# Epoch 7/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.3080 - binary_accuracy: 0.8085
# Epoch 8/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.2816 - binary_accuracy: 0.8085
# Epoch 9/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.2580 - binary_accuracy: 0.8221
# Epoch 10/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.2410 - binary_accuracy: 0.9055
# Epoch 11/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.2230 - binary_accuracy: 0.9209
# Epoch 12/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.2076 - binary_accuracy: 0.9294
# Epoch 13/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.1932 - binary_accuracy: 0.9404
# Epoch 14/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.1780 - binary_accuracy: 0.9540
# Epoch 15/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.1616 - binary_accuracy: 0.9498
# Epoch 16/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.1426 - binary_accuracy: 0.9617
# Epoch 17/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.1188 - binary_accuracy: 0.9728
# Epoch 18/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0980 - binary_accuracy: 0.9745
# Epoch 19/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0780 - binary_accuracy: 0.9830
# Epoch 20/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0663 - binary_accuracy: 0.9838
# Epoch 21/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0617 - binary_accuracy: 0.9838
# Epoch 22/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0443 - binary_accuracy: 0.9915
# Epoch 23/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0416 - binary_accuracy: 0.9940
# Epoch 24/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0368 - binary_accuracy: 0.9940
# Epoch 25/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0299 - binary_accuracy: 0.9957
# Epoch 26/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0227 - binary_accuracy: 0.9974
# Epoch 27/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0184 - binary_accuracy: 0.9991
# Epoch 28/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0148 - binary_accuracy: 0.9991
# Epoch 29/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0127 - binary_accuracy: 1.0000
# Epoch 30/64
# 1175/1175 [==============================] - 0s 33us/step - loss: 0.0143 - binary_accuracy: 0.9991
# Epoch 31/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0119 - binary_accuracy: 0.9991
# Epoch 32/64
# 1175/1175 [==============================] - 0s 36us/step - loss: 0.0116 - binary_accuracy: 0.9983
# Epoch 33/64
# 1175/1175 [==============================] - 0s 34us/step - loss: 0.0086 - binary_accuracy: 1.0000
# Epoch 34/64
# 1175/1175 [==============================] - 0s 37us/step - loss: 0.0080 - binary_accuracy: 1.0000
# Epoch 35/64
# 1175/1175 [==============================] - 0s 35us/step - loss: 0.0076 - binary_accuracy: 1.0000
# Epoch 36/64
# ...
# Epoch 8/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.3005 - binary_accuracy: 0.8142
# Epoch 9/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.2752 - binary_accuracy: 0.8142
# Epoch 10/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.2553 - binary_accuracy: 0.8142
# Epoch 11/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.2367 - binary_accuracy: 0.8346
# Epoch 12/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.2212 - binary_accuracy: 0.8875
# Epoch 13/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.2104 - binary_accuracy: 0.9318
# Epoch 14/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1988 - binary_accuracy: 0.9139
# Epoch 15/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.1873 - binary_accuracy: 0.9395
# Epoch 16/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1757 - binary_accuracy: 0.9446
# Epoch 17/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.1689 - binary_accuracy: 0.9633
# Epoch 18/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1612 - binary_accuracy: 0.9540
# Epoch 19/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1508 - binary_accuracy: 0.9659
# Epoch 20/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1439 - binary_accuracy: 0.9753
# Epoch 21/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1410 - binary_accuracy: 0.9829
# Epoch 22/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1336 - binary_accuracy: 0.9821
# Epoch 23/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1249 - binary_accuracy: 0.9829
# Epoch 24/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1175 - binary_accuracy: 0.9855
# Epoch 25/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1092 - binary_accuracy: 0.9923
# Epoch 26/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1040 - binary_accuracy: 0.9923
# Epoch 27/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.1019 - binary_accuracy: 0.9974
# Epoch 28/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0937 - binary_accuracy: 0.9983
# Epoch 29/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0883 - binary_accuracy: 0.9983
# Epoch 30/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0848 - binary_accuracy: 0.9957
# Epoch 31/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0804 - binary_accuracy: 0.9983
# Epoch 32/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0777 - binary_accuracy: 0.9949
# Epoch 33/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0731 - binary_accuracy: 0.9983
# Epoch 34/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0673 - binary_accuracy: 0.9983
# Epoch 35/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0618 - binary_accuracy: 1.0000
# Epoch 36/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0582 - binary_accuracy: 0.9983
# Epoch 37/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0538 - binary_accuracy: 0.9991
# Epoch 38/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0512 - binary_accuracy: 0.9983
# Epoch 39/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0472 - binary_accuracy: 0.9991
# Epoch 40/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0421 - binary_accuracy: 1.0000
# Epoch 41/64
# 1173/1173 [==============================] - 0s 40us/step - loss: 0.0394 - binary_accuracy: 0.9991
# Epoch 42/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0347 - binary_accuracy: 0.9991
# Epoch 43/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0303 - binary_accuracy: 1.0000
# Epoch 44/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0253 - binary_accuracy: 0.9991
# Epoch 45/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0197 - binary_accuracy: 0.9991
# Epoch 46/64
# 1173/1173 [==============================] - 0s 34us/step - loss: 0.0146 - binary_accuracy: 1.0000
# Epoch 47/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0126 - binary_accuracy: 1.0000
# Epoch 48/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0097 - binary_accuracy: 1.0000
# Epoch 49/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0094 - binary_accuracy: 1.0000
# Epoch 50/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0106 - binary_accuracy: 0.9991
# Epoch 51/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0078 - binary_accuracy: 1.0000
# Epoch 52/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0054 - binary_accuracy: 1.0000
# Epoch 53/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0060 - binary_accuracy: 0.9991
# Epoch 54/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0047 - binary_accuracy: 1.0000
# Epoch 55/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0037 - binary_accuracy: 1.0000
# Epoch 56/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0095 - binary_accuracy: 1.0000
# Epoch 57/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0057 - binary_accuracy: 1.0000
# Epoch 58/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0047 - binary_accuracy: 0.9991
# Epoch 59/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 60/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 61/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 62/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 63/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 64/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 1/64
# 1173/1173 [==============================] - 2s 1ms/step - loss: 0.6377 - binary_accuracy: 0.7732
# Epoch 2/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.5168 - binary_accuracy: 0.7988
# Epoch 3/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.4892 - binary_accuracy: 0.7988
# Epoch 4/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.4665 - binary_accuracy: 0.7988
# Epoch 5/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.4363 - binary_accuracy: 0.7988
# Epoch 6/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.4046 - binary_accuracy: 0.7988
# Epoch 7/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.3754 - binary_accuracy: 0.7988
# Epoch 8/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.3507 - binary_accuracy: 0.7997
# Epoch 9/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.3222 - binary_accuracy: 0.8414
# Epoch 10/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.2932 - binary_accuracy: 0.8568
# Epoch 11/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.2576 - binary_accuracy: 0.8960
# Epoch 12/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.2282 - binary_accuracy: 0.9105
# Epoch 13/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.2071 - binary_accuracy: 0.9182
# Epoch 14/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.1699 - binary_accuracy: 0.9352
# Epoch 15/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.1466 - binary_accuracy: 0.9471
# Epoch 16/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.1260 - binary_accuracy: 0.9599
# Epoch 17/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.1065 - binary_accuracy: 0.9668
# Epoch 18/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.1021 - binary_accuracy: 0.9676
# Epoch 19/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0704 - binary_accuracy: 0.9821
# Epoch 20/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0621 - binary_accuracy: 0.9821
# Epoch 21/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0577 - binary_accuracy: 0.9881
# Epoch 22/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0468 - binary_accuracy: 0.9906
# Epoch 23/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0415 - binary_accuracy: 0.9898
# Epoch 24/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0375 - binary_accuracy: 0.9932
# Epoch 25/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0289 - binary_accuracy: 0.9940
# Epoch 26/64
# 1173/1173 [==============================] - 0s 39us/step - loss: 0.0259 - binary_accuracy: 0.9966
# Epoch 27/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0311 - binary_accuracy: 0.9932
# Epoch 28/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0179 - binary_accuracy: 0.9983
# Epoch 29/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0155 - binary_accuracy: 1.0000
# Epoch 30/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0139 - binary_accuracy: 0.9991
# Epoch 31/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0142 - binary_accuracy: 0.9991
# Epoch 32/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0144 - binary_accuracy: 0.9991
# Epoch 33/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0140 - binary_accuracy: 0.9991
# Epoch 34/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0118 - binary_accuracy: 0.9983
# Epoch 35/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0101 - binary_accuracy: 0.9991
# Epoch 36/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0094 - binary_accuracy: 0.9991
# Epoch 37/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0072 - binary_accuracy: 1.0000
# Epoch 38/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0079 - binary_accuracy: 0.9983
# Epoch 39/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0089 - binary_accuracy: 0.9991
# Epoch 40/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0074 - binary_accuracy: 0.9983
# Epoch 41/64
# 1173/1173 [==============================] - 0s 40us/step - loss: 0.0058 - binary_accuracy: 1.0000
# Epoch 42/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0051 - binary_accuracy: 1.0000
# Epoch 43/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 44/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0029 - binary_accuracy: 1.0000
# Epoch 45/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0033 - binary_accuracy: 1.0000
# Epoch 46/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0029 - binary_accuracy: 1.0000
# Epoch 47/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0032 - binary_accuracy: 1.0000
# Epoch 48/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0028 - binary_accuracy: 1.0000
# Epoch 49/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 50/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0024 - binary_accuracy: 1.0000
# Epoch 51/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 52/64
# 1173/1173 [==============================] - 0s 36us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 53/64
# 1173/1173 [==============================] - 0s 40us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 54/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 55/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 56/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 57/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 58/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 59/64
# 1173/1173 [==============================] - 0s 38us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 60/64
# 1173/1173 [==============================] - 0s 40us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 61/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 62/64
# 1173/1173 [==============================] - 0s 37us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 63/64
# 1173/1173 [==============================] - ETA: 0s - loss: 0.0017 - binary_accuracy: 1.000 - 0s 36us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 64/64
# 1173/1173 [==============================] - 0s 35us/step - loss: 0.0013 - binary_accuracy: 1.0000
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.793
#   precision           0.682
#   recall              0.688
#   f1                  0.685
#   confusion matrix:
#   [[   308     35]
#    [    34     75]]
#
# label: death
#   balanced_accuracy   0.661
#   precision           0.548
#   recall              0.556
#   f1                  0.552
#   confusion matrix:
#   [[   229     70]
#    [    68     85]]
#
# label: power
#   balanced_accuracy   0.775
#   precision           0.833
#   recall              0.571
#   f1                  0.678
#   confusion matrix:
#   [[   374      8]
#    [    30     40]]
#
# label: thrash
#   balanced_accuracy   0.655
#   precision           0.518
#   recall              0.382
#   f1                  0.439
#   confusion matrix:
#   [[   349     27]
#    [    47     29]]
#
# Average binary classification scores:
#   balanced_accuracy   0.72 +/- 0.13
#   precision           0.65 +/- 0.25
#   recall              0.55 +/- 0.22
#   f1                  0.59 +/- 0.20
#
# Multi-label classification metrics:
#   accuracy      0.46
#   precision     0.64
#   recall        0.58
#   f1            0.61
#   hamming loss  0.71
#
# ROC AUC scores:
#   black     : 0.896
#   death     : 0.760
#   power     : 0.909
#   thrash    : 0.784
#   macro-avg : 0.837 +/- 0.066
#
# ------------------------
# Cross-validation results
#
# Binary classification metrics:
#
# label: black
#   balanced_accuracy   0.791
#   precision           0.577
#   recall              0.757
#   f1                  0.655
#   confusion matrix:
#   [[   850    180]
#    [    79    246]]
#
# label: death
#   balanced_accuracy   0.699
#   precision           0.532
#   recall              0.721
#   f1                  0.612
#   confusion matrix:
#   [[   607    290]
#    [   128    330]]
#
# label: power
#   balanced_accuracy   0.832
#   precision           0.535
#   recall              0.790
#   f1                  0.638
#   confusion matrix:
#   [[  1001    144]
#    [    44    166]]
#
# label: thrash
#   balanced_accuracy   0.741
#   precision           0.369
#   recall              0.737
#   f1                  0.492
#   confusion matrix:
#   [[   840    287]
#    [    60    168]]
#
# Average binary classification scores:
#   balanced_accuracy   0.77 +/- 0.10
#   precision           0.50 +/- 0.16
#   recall              0.75 +/- 0.05
#   f1                  0.60 +/- 0.13
#
# Multi-label classification metrics:
#   accuracy      0.48
#   precision     0.53
#   recall        0.77
#   f1            0.63
#   hamming loss  0.89
#
# ROC AUC scores:
#   black     : 0.877
#   death     : 0.770
#   power     : 0.911
#   thrash    : 0.809
#   macro-avg : 0.842 +/- 0.055

# %%
print(keras_mlc.threshold)
keras_pipeline.fit(X, y, labels=genres, verbose=0)
keras_pipeline.set_threshold(keras_mlc.threshold)

for text in test_corpus:
    print(text)
    keras_pipeline.classify_text(text)
    print()
# Out:
# [0.02514472 0.03252989 0.00031911 0.00383191]
# 100%|███████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 818.55it/s]
# Epoch 1/64
# 1761/1761 [==============================] - 1s 378us/step - loss: 0.6021 - binary_accuracy: 0.7456
# Epoch 2/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.5041 - binary_accuracy: 0.7575
# Epoch 3/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.4360 - binary_accuracy: 0.7615
# Epoch 4/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.3788 - binary_accuracy: 0.8154
# Epoch 5/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.3377 - binary_accuracy: 0.8518
# Epoch 6/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.3024 - binary_accuracy: 0.8768
# Epoch 7/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2730 - binary_accuracy: 0.8898
# Epoch 8/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2350 - binary_accuracy: 0.9080
# Epoch 9/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2110 - binary_accuracy: 0.9137
# Epoch 10/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1730 - binary_accuracy: 0.9387
# Epoch 11/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1447 - binary_accuracy: 0.9506
# Epoch 12/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1307 - binary_accuracy: 0.9563
# Epoch 13/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1024 - binary_accuracy: 0.9699
# Epoch 14/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0812 - binary_accuracy: 0.9767
# Epoch 15/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0705 - binary_accuracy: 0.9784
# Epoch 16/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0602 - binary_accuracy: 0.9847
# Epoch 17/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0515 - binary_accuracy: 0.9898
# Epoch 18/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0412 - binary_accuracy: 0.9926
# Epoch 19/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0308 - binary_accuracy: 0.9920
# Epoch 20/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0273 - binary_accuracy: 0.9960
# Epoch 21/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0230 - binary_accuracy: 0.9966
# Epoch 22/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0173 - binary_accuracy: 0.9966
# Epoch 23/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0168 - binary_accuracy: 0.9972
# Epoch 24/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0130 - binary_accuracy: 0.9983
# Epoch 25/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0164 - binary_accuracy: 0.9972
# Epoch 26/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0104 - binary_accuracy: 0.9983
# Epoch 27/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0082 - binary_accuracy: 1.0000
# Epoch 28/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0092 - binary_accuracy: 0.9994
# Epoch 29/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0074 - binary_accuracy: 0.9994
# Epoch 30/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0066 - binary_accuracy: 1.0000
# Epoch 31/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0067 - binary_accuracy: 0.9989
# Epoch 32/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0046 - binary_accuracy: 1.0000
# Epoch 33/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0050 - binary_accuracy: 0.9994
# Epoch 34/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0048 - binary_accuracy: 1.0000
# Epoch 35/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0033 - binary_accuracy: 1.0000
# Epoch 36/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0041 - binary_accuracy: 1.0000
# Epoch 37/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0030 - binary_accuracy: 1.0000
# Epoch 38/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0034 - binary_accuracy: 0.9994
# Epoch 39/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 40/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 41/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 42/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0016 - binary_accuracy: 1.0000
# Epoch 43/64
# 1761/1761 [==============================] - 0s 32us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 44/64
# 1761/1761 [==============================] - 0s 29us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 45/64
# 1761/1761 [==============================] - 0s 28us/step - loss: 0.0016 - binary_accuracy: 1.0000
# Epoch 46/64
# 1761/1761 [==============================] - 0s 30us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 47/64
# 1761/1761 [==============================] - 0s 29us/step - loss: 0.0023 - binary_accuracy: 0.9994
# Epoch 48/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 49/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 50/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 51/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 52/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 53/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 9.2887e-04 - binary_accuracy: 1.0000
# Epoch 54/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0010 - binary_accuracy: 1.0000
# Epoch 55/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 56/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 57/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0011 - binary_accuracy: 1.0000
# Epoch 58/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 7.9885e-04 - binary_accuracy: 1.0000
# Epoch 59/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 9.4290e-04 - binary_accuracy: 1.0000
# Epoch 60/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 5.5809e-04 - binary_accuracy: 1.0000
# Epoch 61/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 8.3688e-04 - binary_accuracy: 1.0000
# Epoch 62/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 5.3009e-04 - binary_accuracy: 1.0000
# Epoch 63/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 7.4748e-04 - binary_accuracy: 1.0000
# Epoch 64/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 6.8419e-04 - binary_accuracy: 1.0000
# Epoch 1/64
# 1761/1761 [==============================] - 1s 394us/step - loss: 0.6604 - binary_accuracy: 0.6428
# Epoch 2/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.6102 - binary_accuracy: 0.6564
# Epoch 3/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.5522 - binary_accuracy: 0.7149
# Epoch 4/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.5092 - binary_accuracy: 0.7666
# Epoch 5/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.4787 - binary_accuracy: 0.7916
# Epoch 6/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.4544 - binary_accuracy: 0.7859
# Epoch 7/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.4215 - binary_accuracy: 0.8120
# Epoch 8/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.3837 - binary_accuracy: 0.8268
# Epoch 9/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.3493 - binary_accuracy: 0.8552
# Epoch 10/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.3314 - binary_accuracy: 0.8524
# Epoch 11/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2732 - binary_accuracy: 0.8904
# Epoch 12/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2641 - binary_accuracy: 0.9023
# Epoch 13/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2289 - binary_accuracy: 0.9131
# Epoch 14/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2006 - binary_accuracy: 0.9273
# Epoch 15/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1742 - binary_accuracy: 0.9398
# Epoch 16/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1434 - binary_accuracy: 0.9563
# Epoch 17/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1291 - binary_accuracy: 0.9574
# Epoch 18/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1108 - binary_accuracy: 0.9682
# Epoch 19/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0871 - binary_accuracy: 0.9790
# Epoch 20/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0774 - binary_accuracy: 0.9807
# Epoch 21/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0632 - binary_accuracy: 0.9852
# Epoch 22/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0667 - binary_accuracy: 0.9801
# Epoch 23/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0509 - binary_accuracy: 0.9892
# Epoch 24/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0435 - binary_accuracy: 0.9926
# Epoch 25/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0408 - binary_accuracy: 0.9932
# Epoch 26/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0311 - binary_accuracy: 0.9966
# Epoch 27/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0281 - binary_accuracy: 0.9966
# Epoch 28/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0244 - binary_accuracy: 0.9977
# Epoch 29/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0227 - binary_accuracy: 0.9960
# Epoch 30/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0200 - binary_accuracy: 0.9977
# Epoch 31/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0191 - binary_accuracy: 0.9972
# Epoch 32/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0160 - binary_accuracy: 0.9989
# Epoch 33/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0133 - binary_accuracy: 0.9994
# Epoch 34/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0127 - binary_accuracy: 0.9989
# Epoch 35/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0131 - binary_accuracy: 0.9983
# Epoch 36/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0125 - binary_accuracy: 0.9983
# Epoch 37/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0104 - binary_accuracy: 0.9994
# Epoch 38/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0091 - binary_accuracy: 0.9994
# Epoch 39/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0079 - binary_accuracy: 0.9989
# Epoch 40/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0070 - binary_accuracy: 0.9994
# Epoch 41/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0069 - binary_accuracy: 0.9989
# Epoch 42/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0070 - binary_accuracy: 1.0000
# Epoch 43/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0066 - binary_accuracy: 0.9989
# Epoch 44/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0055 - binary_accuracy: 0.9994
# Epoch 45/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0063 - binary_accuracy: 0.9994
# Epoch 46/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0043 - binary_accuracy: 1.0000
# Epoch 47/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0050 - binary_accuracy: 1.0000
# Epoch 48/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0042 - binary_accuracy: 1.0000
# Epoch 49/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 50/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0039 - binary_accuracy: 1.0000
# Epoch 51/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0037 - binary_accuracy: 1.0000
# Epoch 52/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0033 - binary_accuracy: 0.9994
# Epoch 53/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0038 - binary_accuracy: 1.0000
# Epoch 54/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0035 - binary_accuracy: 0.9994
# Epoch 55/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 56/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0023 - binary_accuracy: 1.0000
# Epoch 57/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0044 - binary_accuracy: 0.9989
# Epoch 58/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 59/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 60/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 61/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0019 - binary_accuracy: 1.0000
# Epoch 62/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 63/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0029 - binary_accuracy: 0.9994
# Epoch 64/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 1/64
# 1761/1761 [==============================] - 1s 416us/step - loss: 0.5849 - binary_accuracy: 0.7939
# Epoch 2/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.4878 - binary_accuracy: 0.8189
# Epoch 3/64
# 1761/1761 [==============================] - 0s 28us/step - loss: 0.4343 - binary_accuracy: 0.8189
# Epoch 4/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.3740 - binary_accuracy: 0.8189
# Epoch 5/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.3176 - binary_accuracy: 0.8189
# Epoch 6/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2760 - binary_accuracy: 0.8631
# Epoch 7/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.2424 - binary_accuracy: 0.8893
# Epoch 8/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.2163 - binary_accuracy: 0.9052
# Epoch 9/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.1888 - binary_accuracy: 0.9205
# Epoch 10/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1695 - binary_accuracy: 0.9267
# Epoch 11/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.1464 - binary_accuracy: 0.9409
# Epoch 12/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.1422 - binary_accuracy: 0.9443
# Epoch 13/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.1282 - binary_accuracy: 0.9512
# Epoch 14/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.1021 - binary_accuracy: 0.9637
# Epoch 15/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0887 - binary_accuracy: 0.9676
# Epoch 16/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0863 - binary_accuracy: 0.9682
# Epoch 17/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0679 - binary_accuracy: 0.9796
# Epoch 18/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0584 - binary_accuracy: 0.9835
# Epoch 19/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0485 - binary_accuracy: 0.9864
# Epoch 20/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0420 - binary_accuracy: 0.9898
# Epoch 21/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0354 - binary_accuracy: 0.9926
# Epoch 22/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0261 - binary_accuracy: 0.9943
# Epoch 23/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0225 - binary_accuracy: 0.9955
# Epoch 24/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0216 - binary_accuracy: 0.9955
# Epoch 25/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0195 - binary_accuracy: 0.9955
# Epoch 26/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0151 - binary_accuracy: 0.9977
# Epoch 27/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0150 - binary_accuracy: 0.9972
# Epoch 28/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0116 - binary_accuracy: 0.9989
# Epoch 29/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0129 - binary_accuracy: 0.9977
# Epoch 30/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0094 - binary_accuracy: 1.0000
# Epoch 31/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0079 - binary_accuracy: 1.0000
# Epoch 32/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0080 - binary_accuracy: 0.9989
# Epoch 33/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0063 - binary_accuracy: 1.0000
# Epoch 34/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0060 - binary_accuracy: 0.9994
# Epoch 35/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0054 - binary_accuracy: 1.0000
# Epoch 36/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0048 - binary_accuracy: 1.0000
# Epoch 37/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0040 - binary_accuracy: 1.0000
# Epoch 38/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0050 - binary_accuracy: 0.9994
# Epoch 39/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0045 - binary_accuracy: 0.9994
# Epoch 40/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0030 - binary_accuracy: 1.0000
# Epoch 41/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0036 - binary_accuracy: 1.0000
# Epoch 42/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0035 - binary_accuracy: 0.9994
# Epoch 43/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0026 - binary_accuracy: 1.0000
# Epoch 44/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 45/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0025 - binary_accuracy: 1.0000
# Epoch 46/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 47/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 48/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0025 - binary_accuracy: 0.9994
# Epoch 49/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 50/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 51/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 52/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 53/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0011 - binary_accuracy: 1.0000
# Epoch 54/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 55/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 56/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 57/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 58/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 59/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 60/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 9.2772e-04 - binary_accuracy: 1.0000
# Epoch 61/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0011 - binary_accuracy: 1.0000
# Epoch 62/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 63/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 64/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0011 - binary_accuracy: 1.0000
# Epoch 1/64
# 1761/1761 [==============================] - 1s 436us/step - loss: 0.6150 - binary_accuracy: 0.7535
# Epoch 2/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.4981 - binary_accuracy: 0.8075
# Epoch 3/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.4549 - binary_accuracy: 0.8075
# Epoch 4/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.4158 - binary_accuracy: 0.8075
# Epoch 5/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.3751 - binary_accuracy: 0.8075
# Epoch 6/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.3443 - binary_accuracy: 0.8285
# Epoch 7/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.3174 - binary_accuracy: 0.8631
# Epoch 8/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.2933 - binary_accuracy: 0.8717
# Epoch 9/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.2655 - binary_accuracy: 0.8955
# Epoch 10/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.2359 - binary_accuracy: 0.9012
# Epoch 11/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.2109 - binary_accuracy: 0.9216
# Epoch 12/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1837 - binary_accuracy: 0.9347
# Epoch 13/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.1618 - binary_accuracy: 0.9438
# Epoch 14/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.1349 - binary_accuracy: 0.9523
# Epoch 15/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.1099 - binary_accuracy: 0.9642
# Epoch 16/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0978 - binary_accuracy: 0.9699
# Epoch 17/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0921 - binary_accuracy: 0.9705
# Epoch 18/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0662 - binary_accuracy: 0.9813
# Epoch 19/64
# 1761/1761 [==============================] - ETA: 0s - loss: 0.1048 - binary_accuracy: 0.960 - 0s 25us/step - loss: 0.0579 - binary_accuracy: 0.9835
# Epoch 20/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0455 - binary_accuracy: 0.9898
# Epoch 21/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0389 - binary_accuracy: 0.9915
# Epoch 22/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0318 - binary_accuracy: 0.9938
# Epoch 23/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0260 - binary_accuracy: 0.9955
# Epoch 24/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0206 - binary_accuracy: 0.9977
# Epoch 25/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0200 - binary_accuracy: 0.9972
# Epoch 26/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0181 - binary_accuracy: 0.9977
# Epoch 27/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0151 - binary_accuracy: 0.9989
# Epoch 28/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0118 - binary_accuracy: 0.9994
# Epoch 29/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0123 - binary_accuracy: 0.9977
# Epoch 30/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0103 - binary_accuracy: 1.0000
# Epoch 31/64
# 1761/1761 [==============================] - 0s 31us/step - loss: 0.0111 - binary_accuracy: 0.9989
# Epoch 32/64
# 1761/1761 [==============================] - 0s 35us/step - loss: 0.0091 - binary_accuracy: 0.9994
# Epoch 33/64
# 1761/1761 [==============================] - 0s 39us/step - loss: 0.0082 - binary_accuracy: 0.9994
# Epoch 34/64
# 1761/1761 [==============================] - 0s 28us/step - loss: 0.0061 - binary_accuracy: 0.9994
# Epoch 35/64
# 1761/1761 [==============================] - 0s 31us/step - loss: 0.0059 - binary_accuracy: 0.9989
# Epoch 36/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0046 - binary_accuracy: 0.9994
# Epoch 37/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0037 - binary_accuracy: 1.0000
# Epoch 38/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0033 - binary_accuracy: 1.0000
# Epoch 39/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0035 - binary_accuracy: 1.0000
# Epoch 40/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0035 - binary_accuracy: 1.0000
# Epoch 41/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0030 - binary_accuracy: 1.0000
# Epoch 42/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0030 - binary_accuracy: 1.0000
# Epoch 43/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0027 - binary_accuracy: 1.0000
# Epoch 44/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0023 - binary_accuracy: 1.0000
# Epoch 45/64
# 1761/1761 [==============================] - 0s 29us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 46/64
# 1761/1761 [==============================] - 0s 29us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 47/64
# 1761/1761 [==============================] - 0s 29us/step - loss: 0.0023 - binary_accuracy: 0.9994
# Epoch 48/64
# 1761/1761 [==============================] - 0s 27us/step - loss: 0.0020 - binary_accuracy: 1.0000
# Epoch 49/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 50/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 51/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0022 - binary_accuracy: 1.0000
# Epoch 52/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0017 - binary_accuracy: 1.0000
# Epoch 53/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0019 - binary_accuracy: 0.9994
# Epoch 54/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0021 - binary_accuracy: 1.0000
# Epoch 55/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 56/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 0.0018 - binary_accuracy: 1.0000
# Epoch 57/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0015 - binary_accuracy: 1.0000
# Epoch 58/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 59/64
# 1761/1761 [==============================] - 0s 24us/step - loss: 9.9443e-04 - binary_accuracy: 1.0000
# Epoch 60/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 61/64
# 1761/1761 [==============================] - 0s 25us/step - loss: 0.0014 - binary_accuracy: 1.0000
# Epoch 62/64
# 1761/1761 [==============================] - 0s 26us/step - loss: 0.0011 - binary_accuracy: 1.0000
# Epoch 63/64
# 1761/1761 [==============================] - 0s 28us/step - loss: 0.0012 - binary_accuracy: 1.0000
# Epoch 64/64
# 1761/1761 [==============================] - 0s 32us/step - loss: 0.0010 - binary_accuracy: 1.0000
#
# Classification:
# BLACK, THRASH, POWER
#
# Individual label probabilities:
# black      22%
# thrash      0%
# power       0%
# death       0%
#
# satan
# Classification:
# BLACK
#
# Individual label probabilities:
# black      91%
# thrash      0%
# death       0%
# power       0%
#
# flesh
# Classification:
# DEATH, BLACK, POWER
#
# Individual label probabilities:
# death     100%
# black      33%
# power       0%
# thrash      0%
#
# fight
# Classification:
# POWER
#
# Individual label probabilities:
# power       8%
# black       0%
# thrash      0%
# death       0%
#
# attack
# Classification:
# THRASH, BLACK
#
# Individual label probabilities:
# thrash     99%
# black       3%
# death       0%
# power       0%

# %% [markdown]
# <a id='stacking'></a>
# # Stacked model

# %%
class StackedModel(BaseEstimator, TransformerMixin):
    def __init__(self, clfs=None, meta_clf=None):
        if clfs is not None:
            self.clfs = clfs
        else:
            self.clfs = []
        self.meta_clf = meta_clf

    def fit(self, X, y, split_test_size=0.2):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_test_size)
        y_prob = np.zeros((X_test.shape[0], len(self.clfs)))
        for j, clf in enumerate(self.clfs):
            clf.fit(X_train, y_train)
            y_prob[:, j] = clf.predict_proba(X_test)[:, 1]
        self.meta_clf.fit(y_prob, y_test)
        return self

    def predict(self, X):
        return self.meta_clf.predict(self._predict_base(X))

    def predict_proba(self, X):
        return self.meta_clf.predict_proba(self._predict_base(X))

    def _predict_base(self, X):
        y_prob = np.zeros((X.shape[0], len(self.clfs)))
        for j, clf in enumerate(self.clfs):
            y_prob[:, j] = clf.predict_proba(X)[:, 1]
        return y_prob

# %%
lgb_params = dict(
    n_estimators=1000,
    max_depth=30,
    n_jobs=-1,
    random_state=0
)
lr_params = dict(
    solver='lbfgs',
    max_iter=1000,
    random_state=0
)
stacked_model = StackedModel(
    [
        MultinomialNB(),
        BernoulliNB(),
        lgb.LGBMClassifier(**lgb_params),
    ],
    LogisticRegression(**lr_params)
)
pipeline = Pipeline(
    vectorizer=TfidfVectorizer(stop_words=stopwords, max_features=3000),
    resampler=MLSOL(perc_gen_instances=0.3, k=5),
    classifier=BinaryRelevance(stacked_model, require_dense=[False, True])
)
mlc, _ = multilabel_pipeline_cross_val(pipeline, X, y, labels=genres)
mlc.print_report()
best_thresh = mlc.thresh
if isinstance(best_thresh, float):
    best_thresh = np.ones(mlc.n_labels) * best_thresh
if len(best_thresh.shape) == 2:
    best_thresh = best_thresh.mean(0)
print("\nDecision thresholds:")
for i, label in enumerate(mlc.labels):
    print(f"  {label:<10s}: {best_thresh[i]:.2f}")
mlc.plot_roc_curve()
plt.show()
mlc.plot_precision_recall_curve()
plt.show()

# %% [markdown]
# ## Stacking with NN

# %%
lgb_params = dict(
    n_estimators=1000,
    max_depth=30,
    n_jobs=-1,
    random_state=0
)
lr_params = dict(
    solver='lbfgs',
    max_iter=1000,
    random_state=0
)
keras_params = dict(
    input_dim=3000,
    epochs=1,
    batch_size=512,
)
stacked_model = StackedModel(
    [
        MultinomialNB(),
        BernoulliNB(),
        lgb.LGBMClassifier(**lgb_params),
        KerasClassifier(create_keras_model, **keras_params)
    ],
    LogisticRegression(**lr_params)
)
pipeline = Pipeline(
    vectorizer=TfidfVectorizer(
        stop_words=stopwords, max_features=3000),
    resampler=MLSOL(perc_gen_instances=0.3, k=5),
    classifier=BinaryRelevance(stacked_model, require_dense=[False, True])
)
mlc, _ = multilabel_pipeline_cross_val(pipeline, X, y, labels=genres)
mlc.print_report()
best_thresh = mlc.thresh
if isinstance(best_thresh, float):
    best_thresh = np.ones(mlc.n_labels) * best_thresh
if len(best_thresh.shape) == 2:
    best_thresh = best_thresh.mean(0)
print("\nDecision thresholds:")
for i, label in enumerate(mlc.labels):
    print(f"  {label:<10s}: {best_thresh[i]:.2f}")
mlc.plot_roc_curve()
plt.show()
mlc.plot_precision_recall_curve()
plt.show()

# %% [markdown]
# <a id='test'></a>
# # Test on select lyrics

# %%
# lr_params = dict(
#     solver='lbfgs',
#     max_iter=1000,
#     random_state=0
# )
# pipeline = Pipeline(
#     vectorizer=TfidfVectorizer(stop_words=stopwords, max_features=3000),
#     resampler=MLSOL(perc_gen_instances=0.3, k=5),
#     classifier=BinaryRelevance(
#         LogisticRegression(**lr_params),
#         require_dense=[False, True]
#     )
# )

pipeline = Pipeline(
    vectorizer=TfidfVectorizer(stop_words=stopwords, max_features=3000),
    resampler=MLSOL(perc_gen_instances=0.3, k=5),
    classifier=BinaryRelevance(
        MultinomialNB(),
        require_dense=[False, True]
    )
)
pipeline.fit(X, y)

# %%
def classify_text(text):
    X_test = np.array([' '.join(text.lower().split())])
    prob = pipeline.predict(X_test)[0]
    pred = prob > best_thresh
    genre_results = [(genre, prob[i], pred[i]) for i, genre in enumerate(genres)]
    genre_results.sort(key=lambda x: 1 - x[1])
    print("Classification:")
    if genre_results[0][2] < 1:
        print("NONE")
    else:
        print(", ".join([res[0].upper() for res in genre_results if res[2] > 0]))
    print("\nIndividual genre probabilities:")
    for res in genre_results:
        print("{:<10s}{:>3.0f}%".format(res[0], 100 * res[1]))
    return

# %%
# Deathspell Omega
classify_text("""
Our skies are forever black
Here is no signs of life at all
For burning spirits we are
Consuming your small universe
Slowly but surely
No one believes in us
We came from realms of Hell
No eyes can see us
We're not made of flesh and blood
In times past we reigned everywhere
One day life emerged from the chaos
We still dominate but this error must end
The void shall swallow the decease
Slowly but surely
Changing from a dimention to another..
of being possession
Out of the nihilistic kingdom
to spread destruction
An unseen invasion to conquer
the spiled land...till total extinxion
The human claim to rule their world
They don't even understand the meaning
of death
A black hole is eating each soul
The ultimate desolation will supress
life and prevail again
Then there won't be mistakes anymore
The apotheosis of Satan approaches
He who is inside of us
""")
# Out:
# Classification:
# DEATH, BLACK
#
# Individual genre probabilities:
# death      52%
# black      48%
# thrash      7%
# power       3%

# %%
# Lamb of God
classify_text("""
If there was a single day I could live... a single breath I could take
I'd trade all the others away.
The blood's on the wall, so you'd might as well just admit it
And bleach out the stains, commit to forgetting it.
You're better off empty and blank, than left with a single pathetic trace of this
Smother another failure, lay this to rest.
Console yourself, you're better alone
Destroy yourself, see who gives a fuck
Absorb yourself, you're better alone
Destroy yourself.
I'll chain you to the truth, for the truth shall set you free
I'll turn the screws of vengeance and bury you with honesty
I'll make all your dreams come to life, then slay them as quickly as they came
Smother another failure, lay this to rest.
Console yourself, you're better alone
Destroy yourself, see who gives a fuck
Absorb yourself, you're better alone
Destroy yourself, see who gives a fuck.
Failure.
If there was a day I could live, if there was a single breath I could take
I'd trade all the others away.
""")
# Out:
# Classification:
# NONE
#
# Individual genre probabilities:
# black      24%
# thrash     11%
# death      10%
# power       5%

# %%
# Nokturnal Mortum
classify_text("""
The edge of continuity for dream and reality.
Shaman is dancing his dance of death;
the masks of the demonssurrounding me.
This is my wedding ritual that gives the violence.
The fog of the night, the dark water...
to run through the expanse of light.
The mysteries of civilizations
that left the Earth more of ten times return to me;
it gives no repose to me again and again.
Standing in the forestand seeing the atricities...
all is inside me, and it comes back in the dreams.
The shaman dances, the masks are waiting for its demon.
The knife is in my hand.
The fog... will never crawl away.
My words are devoured by the bestial of silence
and in invisible chains shackle my moves.
The dream continues it's gush to reality
and the shaman drums louder the rhytm to his dance of death.
""")
# Out:
# Classification:
# NONE
#
# Individual genre probabilities:
# black      29%
# death      12%
# thrash     10%
# power       4%

# %%
# Waking the Cadaver
classify_text("""
Full force assault,
With my arsenal,
Of destruction,

Seeing the neighborhood,
With a horrid stare,
Blasting authority,

You will never catch me,
On my killing spree,
Appetite for death,
Realize there is no God.

You will never catch me,
On my killing spree,
Appetite for death,
Realize there is no God.

Full force assault,
With my arsenal,
Of destruction,

Seeing the neighborhood,
With a horrid stare,
Blasting authority,

You will never catch me,
On my killing spree,
Appetite for death,
Realize there is no God.
""")
# Out:
# Classification:
# THRASH
#
# Individual genre probabilities:
# thrash     36%
# black      20%
# death      18%
# power       2%

# %%
# Wolves in the Throne Room
classify_text("""
The journey is long and steep
Sweat turns lack and runs with dust
Here I seek the edge of the world
The secrets that lie behind the veil
The rapture of the universe

As the sun pours down like honey
Three sentries loom at the skyline
Bravely staring on
Our sun of eternity pours down as it shines bright

Many souls slumber
On the mountainside below
Dressed in royal robes of green and red

My left hand points to the earth
My right towards the starry sky
Writhing serpent belt of eternity
Wrapped round my waist
Black banner blows in the wind
Emblazoned with the white rose of death

Under the cover of night, by fire light
Blood smoke in my lungs
Moss and blood in my hair
Ash in my eyes, I grip the torch
My light illuminates her ritual
Lost sigil burns in the dark
Her ecstasy shakes the cannon
The future now glows with a blue brilliance
In my mind's eye I can see a stronghold
With a moat of pure spring water
Spires of cedar and fir
""")
# Out:
# Classification:
# BLACK
#
# Individual genre probabilities:
# black      40%
# death      10%
# thrash      6%
# power       5%

# %%
# Ne Obliviscaris
classify_text("""
ALL HORIZONS FALL THROUGH DYING STAINS
A CRIMSON CROWN TO CALL MY OWN
O HOME IS EVERYWHERE I VOYAGE
AND DARKNESS IS ALWAYS WITH ME...

I CALL TO THE SIRENS ECHOING IN SWEET LAUGHTER
BROKEN HOPES 'NEATH THE SURFACE
WITH HAUNTING EYES THEY STARE...
through black waters, wearing tresses
a figurehead warped, stares homesick afar

NEVER DEPTHS... MY DEAR DESPAIR
NEVER

BLIND IN DELIRIUM, NAVIGATING THE CONTINUUM FLUX... NOTHING
SUBMERGED IN LIMBO, OF NAUTICA THEY SING... TRUE MAJESTY
OCEANS WIDE, EYES WIDE... FOREVER TO TREASURE... CARRY ON
INFUSING INSIGHT, THE FABRIC OF SPACE IGNITED

silent time reveals tragedies chartered
all triumphs were drowned...and the sirens too...
SILENT TIME REVEALS...
ALL TRIUMPHS WERE DROWNED...
symphony for the pilgrim, intrinsic wake, opulent discordant soul... my arabesque
setting sail from paradox lost to a paradise found
PARADISE, PARADISE FOUND
PARADISE, PARADISE FOUND
""")
# Out:
# Classification:
# NONE
#
# Individual genre probabilities:
# black      26%
# death      13%
# power       6%
# thrash      5%

# %%
# Car Bomb
classify_text("""
Dark smiles saying nothing
The warpath, straight and lonely
Both sides feel the cold front closing in

Reveal the frozen pieces of earth

Can’t hear the hidden sounds from its closed mouth
No more secret truths said into the soundproof walls

They sing we’re restored to life

From the dust of this planet you sing
Stand up and sing
Ashes in ears
There’s no way home
Just sing this song

They sing we’re restored to life
Pull the rusting nails from these walls
Peel off your broken nails

Wake wake up the sun
Just take it all back
""")
# Out:
# Classification:
# NONE
#
# Individual genre probabilities:
# black      21%
# thrash      8%
# power       4%
# death       4%

# %%
# Death Angel
classify_text("""
Metal mayhem; hit the stage
Thrashing to the madness,
You can feel the rage!

Denim, leather, in the crowd
Feel your ears are bleeding,
Wanna hear it loud!

Thrasher! [4x]

Posers strike us in the back
I can’t take their bullshit,
Turn around and attack
(Attack!)

Metal bodies slamming into me,
How I live my life
And baby can’t you see?

Thrashers! [4x]

Smashing, thrashing, on your knees
You beg for mercy
Smashing, thrashing, on your knees
You plead for mercy

Thrasher! [4x]

Fighting, fall off the stage
Screaming with a rage
Thrashing, lose control
Smashing I like drugs
Madness, all around
Falling to the ground
Dying for your breath
Living to your death

Thrashing, smashing, on their knees
You beg for mercy
Thrashing, smashing, on their knees
You plead for mercy

Thrasher! [4x]
""")
# Out:
# Classification:
# THRASH
#
# Individual genre probabilities:
# thrash     41%
# death      18%
# black      15%
# power       4%

# %%
# Fleshgod Apocalypse
classify_text("""
Bow your head before your king, as I’m the bringer of light
The chosen one amongst all men, the lord and master of light
“But who decided it all?”
Shut up you servant,, respect divine right
For I belong to the elite of mankind
Enlightened guardian of justice and right
My word is law or it’s eye for an eye

Bow down before the sovereign of the kingdom
I will lead you through the hardest times
Devote we are to the crown, in sole command forever glorious

Hail: Long live the great king!

Born with the fire inside
The flame of wisdom burns in my noble heart
Turns into guiding light that blows the mist on the path
“We’ll follow you ‘till the end!”
Balance of power, the art of the wise
Ancestral pride to preserve for my bloodline
Resounds my name through spirals of time
Until kingdom come I

God bless my soul, guide my fury through this cold war
Hunting Judas down
Now free my hands from the spires of the serpent
Death to the traitors of the crown

No one to trust and no one to save
As this court is a den of snakes
Walk alone through this treacherous world
Mutilating the venomous tongue
Your misleading words, hide desire to prevail
In this devious show, fail

No one is virtuous, no one is grown
No one deserves to be heir to the throne
‘Till their veins will be filled with their gall
I will stand for the sake of the sacred crown
Forever at war
You deceiving worms will be smashed by my rage
In the name of god, slayed

In aeternam, draining struggle to serve my reign
With full force restore the integrity
Purify consciences through blood
Extirpate those cancers, dictate my law
‘Till the day of my fall
Beware you’ll pay for your faults
""")
# Out:
# Classification:
# BLACK
#
# Individual genre probabilities:
# black      51%
# power      17%
# death      15%
# thrash     10%

# %%
# Protest the Hero
classify_text("""
Without a word uttered
A comparison is drawn.
A distant future, a cluttered past
Amid the stars.
Vague yet persistent, 
Thought lacking consistency.
Unwilling victim of farce.
The loudest voices scream uninspired.
Their numbers vast, their spirits strong.
Quiet choices sing against the choir
The majority is almost never wrong...
Never wrong... Ever... Never wrong.

A laughable assertion
That there might be some connection
(smoke-filled halls)
Adorn the walls with mirrors and misdirection,
Or let it go. [4x]

No common thread, 
No ties that bind.
Just grasping at threads and keep in mind.
Historical analysis
They play a separate role,
But one contributes more to the whole!

Like a saucer sep...
Let's separate and shuffle off this conflict.
My armament will suffocate (will suffocate),
And leave you feeling useless.

We are your beginning 
And we will be your end.
Affluence permitting, a mutual annihilation.

A laughable assertion
That there might be some connection
(smoke-filled halls)
Adorn the walls with mirrors and misdirection,
Or let it go. [4x]

Discussion moot
Argument ended
An aggressive mute
Strumbling defendant
Fiction versus fantasy
One fact remains unclear
How you pretend both franchises stand soley on one tier?!

We are your beginning 
And we will be your end.
Affluence permitting, a mutual annihilation.

I don't care who shot first
Or for the song and dance you've rehearsed.
(a mutual annihilation)
I don't care who shot first,
Or for the song and dance that you've rehearsed.

The maps are divided
And each are traversed.
Aligment in flux for better or worse.
Is the drain finally swirling or are we swirling the drain?
This drought is relieved with acid rain.

This drought is relieved with acid rain. [3x]

(we are) We are your beginning (and the end)
And we will be your end (we will be your end) [2x]

Affluence permitting a mutual annihilation
""")
# Out:
# Classification:
# NONE
#
# Individual genre probabilities:
# black      17%
# thrash     11%
# death       6%
# power       6%
